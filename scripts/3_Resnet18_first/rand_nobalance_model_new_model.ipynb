# %% [markdown]
# **Importing libraries**

# %%
# Keras e TF

#import tensorflow
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, Conv1D, MaxPooling2D, Dense, Flatten, BatchNormalization, Activation, AveragePooling2D, Input, Flatten, Dropout
from keras.callbacks import ModelCheckpoint

# Sk-Learn
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix, ConfusionMatrixDisplay, roc_curve, roc_auc_score, RocCurveDisplay, accuracy_score, classification_report, confusion_matrix

# Base
import os 
from pathlib import Path
from matplotlib import pyplot as plt
import seaborn as sns # 
import numpy as np #
import pandas as pd # 

from keras.utils import load_img

import pydot
import pydotplus
from pydotplus import graphviz

from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import backend as K
from custom_resnet import ResNet18


from keras.models import Model
from keras.optimizers import Adam

# %%
keras.__version__
tensorflow.__version__
# Out:
# '2.10.1'

# %% [markdown]
# **Setting path to the dataset**

# %%
os.chdir(Path(str(Path(os.getcwd()).parent.absolute().parent.absolute()) +
              '\\adni-images-Full-resized160x192'))

# %%
print(os.getcwd())
# Out:
# d:\Projects\ADNI-brain-MRI-alzheimer-classification-and-GAN-generation\adni-images-Full-resized160x192

# %% [markdown]
# # Loading Dataset

# %%
data_dir = Path(os.getcwd())

def data_mean_std():
    names = []
    for root, dirs, files in os.walk(data_dir):
        if "train" in root:
            for file in files:
                names.append(root + '/' + file)
    
    print(len(names))
                
    array = []
    for name in names:
        try:
            img = load_img(name, color_mode = 'grayscale', target_size = (160, 192))
            img_array = np.asarray(img)
            array.append(img_array)
        except:
            print("Name: ", name)
            continue
    
    print(img_array.shape) # Correct amount of images

    array = np.asarray(array)
    print(array.shape)
    print(array.mean().shape, array.std().shape)
    return array.mean(), array.std()
""" 
stats_file = open(stats_path, 'r')
stats_lst = stats_file.read().split('\n')
mean = float(stats_lst[0])
std = float(stats_lst[1])"""
mean, std = data_mean_std()

print(mean, std)
# Out:
# 218576
# Name:  d:\Projects\ADNI-brain-MRI-alzheimer-classification-and-GAN-generation\adni-images-Full-resized160x192\train_gan_over\ad/fake_ad_19058.png
# (160, 192)
# (218575, 160, 192)
# () ()
# 35.80925715423529 45.16736479384096

# %% [markdown]
# Use the pre-computed values (no_balance):

# %%
mean = 35.80925715423529
std = 45.16736479384096

# %%
def normalize(x):
    return (x - mean) / std

# %%
batch_size = 32 # Batch size

train_path = './train'
test_path = './test'
valid_path = './valid'
#rescale = 1./255.
train_datagen = ImageDataGenerator(rescale=1./255.)
test_datagen = ImageDataGenerator(rescale=1./255.)
valid_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_data = train_datagen.flow_from_directory(
        train_path,
        target_size=(160, 160),  # Lo inserisco per precauzione
        batch_size=batch_size,
        seed=123,
        shuffle=True,
        class_mode='categorical')
# Out:
# Found 218575 images belonging to 3 classes.

# %%
validation_data = valid_datagen.flow_from_directory(
        valid_path,
        target_size=(160, 160),  # Lo inserisco per precauzione
        batch_size=batch_size,
        seed=123,
        shuffle=True,
        class_mode='categorical')
# Out:
# Found 18024 images belonging to 3 classes.

# %%
# Test set
test_data = test_datagen.flow_from_directory(
        test_path,
        target_size=(160, 160),  # Lo inserisco per precauzione
        batch_size=batch_size,
        shuffle=False,
        class_mode='categorical')
# Out:
# Found 10567 images belonging to 3 classes.

# %%
train_data.class_indices
# Out:
# {'ad': 0, 'mci': 1, 'nor': 2}

# %%
validation_data.class_indices
# Out:
# {'ad': 0, 'mci': 1, 'nor': 2}

# %%
test_data.class_indices
# Out:
# {'ad': 0, 'mci': 1, 'nor': 2}

# %%
train_ad = len(os.listdir(os.getcwd() + '\\train\\ad'))
train_nor = len(os.listdir(os.getcwd() + '\\train\\nor'))
train_mci = len(os.listdir(os.getcwd() + '\\train\\mci'))
train_tot = train_ad + train_nor + train_mci
print(train_ad/train_tot, train_nor/train_tot, train_mci/train_tot)
# Out:
# 0.3331854054672309 0.3338396431430859 0.3329749513896832

# %%
test_ad = len(os.listdir(os.getcwd() + '\\test\\ad'))
test_nor = len(os.listdir(os.getcwd() + '\\test\\nor'))
test_mci = len(os.listdir(os.getcwd() + '\\test\\mci'))
test_tot = test_ad + test_nor + test_mci
print(test_ad/test_tot, test_nor/test_tot, test_mci/test_tot)
# Out:
# 0.22504021955143372 0.20762751963660453 0.5673322608119618

# %%
valid_ad = len(os.listdir(os.getcwd() + '\\valid\\ad'))
valid_nor = len(os.listdir(os.getcwd() + '\\valid\\nor'))
valid_mci = len(os.listdir(os.getcwd() + '\\valid\\mci'))
valid_tot = valid_ad + valid_nor + valid_mci
print(valid_ad/valid_tot, valid_nor/valid_tot, valid_mci/valid_tot)
# Out:
# 0.22253661784287618 0.37377940523746117 0.4036839769196627

# %% [markdown]
# # Model Definition

# %% [markdown]
# Changing the folder to data path to save weights into

# %%
os.chdir(Path(str(Path(os.getcwd()).parent.absolute()) + '\\scripts\\3_Resnet18_first'))

# %%
os.getcwd()
# Out:
# 'd:\\Projects\\ADNI-brain-MRI-alzheimer-classification-and-GAN-generation\\scripts\\3_Resnet18_first'

# %%
METRICS = [ 
      keras.metrics.CategoricalAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.TopKCategoricalAccuracy(name='top 2 accuracy', k=2),
      keras.metrics.TopKCategoricalAccuracy(name='top 3 accuracy', k=3),
      keras.metrics.TopKCategoricalAccuracy(name='top 5 accuracy', k=5)
]

# %%
early_stopper = keras.callbacks.EarlyStopping(monitor='val_loss', patience=100)

# %%
tb = TensorBoard(log_dir =os.getcwd() + '\\covidnet_no_balance\\logs_covidnet_no_balance', write_graph = True)

#lr_reducer = ReduceLROnPlateau(monitor='loss', factor=np.sqrt(0.1), patience=10, cooldown=0, min_lr=1e-5)

model_chkp = ModelCheckpoint(filepath=os.getcwd() + '\\covidnet_no_balance\\best_model_covidnet_no_balance',
                            # monitor='val_quadratic_kappa_score',
                            monitor='val_accuracy',
                            save_best_only=True, save_weights_only=True, mode='max')

# %%
num_classes = 3
inputs = keras.Input((160,160,3))

x = inputs

x = keras.layers.Conv2D(16, 3, padding ="same", strides=1)(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.BatchNormalization()(x)

x = keras.layers.Conv2D(32, 3,  padding ="same", strides=1)(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.MaxPooling2D(pool_size=(3,3), strides=(3,3))(x)
x = keras.layers.Dropout(0.2)(x)

x = keras.layers.Conv2D(64, 3,  padding ="same", strides=1)(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.BatchNormalization()(x)

x = keras.layers.Conv2D(128, 2,  padding ="same", strides=1)(x)
x = keras.layers.Activation('relu')(x)

x = keras.layers.MaxPooling2D(pool_size=(2,2), strides=(3,3))(x)

x = keras.layers.Dropout(0.2)(x)

# x = keras.layers.GlobalMaxPool2D()(x)
x = keras.layers.Flatten()(x)

x = keras.layers.Dense(128, activation='relu')(x)
x = keras.layers.Dropout(0.5)(x)

# x = keras.layers.Dense(512, activation='relu')(x)
# x = keras.layers.Dropout(0.5)(x)

# x = keras.layers.Dense(1000, activation='relu')(x)
# x = keras.layers.Dropout(0.5)(x)

outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
ft_resnet = keras.Model(inputs, outputs)

# %%
ft_resnet.summary()

# %%
# #resnet = ResNet18()
# #resnet = ResNet18(classes=3, input_shape=(160, 192))
# resnet = ResNet18(classes=3)


# #model = keras.applications.resnet50.ResNet50(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000)
# #model.summary()

# #resnet.layers.pop()
# #for layer in resnet.layers:
# #    layer.trainable = False

# x = resnet.layers[-1].output

# x = Dropout(0.25)(x)

# x = Dense(3, activation = 'softmax')(x)


# ft_resnet = Model(resnet.input, x)
# optimizer = Adam(learning_rate = 0.001)
# ft_resnet.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = METRICS)

# print("model loaded")

# ft_resnet.summary()

# %% [markdown]
# Changing back the folder to data path

# %%
os.chdir(Path(str(Path(os.getcwd()).parent.absolute().parent.absolute()) + '\\adni-images-Full-resized160x192'))
os.getcwd()
# Out:
# 'd:\\Projects\\ADNI-brain-MRI-alzheimer-classification-and-GAN-generation\\adni-images-Full-resized160x192'

# %%
print(np.ceil(train_tot/batch_size))
print(np.ceil(valid_tot/batch_size))

print(len(train_data.labels) // batch_size)
print(len(validation_data.labels) // batch_size)

# %%
version = "v1"
epochs = 30

print(train_tot, valid_tot)

train_steps = np.ceil(train_tot/batch_size)
valid_steps = np.ceil(valid_tot/batch_size)

print (train_steps, valid_steps)

#fit_generator

history_dcnn = ft_resnet.fit(train_data, 
                             steps_per_epoch=train_steps,
                             epochs=epochs,
                             workers = 4,
                             callbacks = [tb, model_chkp, early_stopper],
                             validation_data = validation_data, 
                             validation_steps = valid_steps)
# Out:
# 218575 18024
# 6831.0 564.0
# Epoch 1/30
# 6831/6831 [==============================] - 424s 61ms/step - loss: 0.5995 - accuracy: 0.7238 - precision: 0.7706 - recall: 0.6622 - auc: 0.8982 - top 2 accuracy: 0.9170 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 17.6043 - val_accuracy: 0.2232 - val_precision: 0.2232 - val_recall: 0.2231 - val_auc: 0.4174 - val_top 2 accuracy: 0.6651 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 2/30
# 6831/6831 [==============================] - 415s 61ms/step - loss: 0.3441 - accuracy: 0.8565 - precision: 0.8750 - recall: 0.8370 - auc: 0.9677 - top 2 accuracy: 0.9700 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 4.9853 - val_accuracy: 0.4128 - val_precision: 0.4141 - val_recall: 0.4066 - val_auc: 0.5856 - val_top 2 accuracy: 0.7452 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 3/30
# 6831/6831 [==============================] - 417s 61ms/step - loss: 0.1705 - accuracy: 0.9342 - precision: 0.9397 - recall: 0.9291 - auc: 0.9916 - top 2 accuracy: 0.9903 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 3.4342 - val_accuracy: 0.3888 - val_precision: 0.3891 - val_recall: 0.3814 - val_auc: 0.5589 - val_top 2 accuracy: 0.7289 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 4/30
# 6831/6831 [==============================] - 416s 61ms/step - loss: 0.0952 - accuracy: 0.9647 - precision: 0.9668 - recall: 0.9628 - auc: 0.9971 - top 2 accuracy: 0.9961 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 18.6375 - val_accuracy: 0.2309 - val_precision: 0.2309 - val_recall: 0.2305 - val_auc: 0.4215 - val_top 2 accuracy: 0.6467 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 5/30
# 6831/6831 [==============================] - 418s 61ms/step - loss: 0.0644 - accuracy: 0.9764 - precision: 0.9776 - recall: 0.9754 - auc: 0.9985 - top 2 accuracy: 0.9979 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 20.6638 - val_accuracy: 0.2390 - val_precision: 0.2389 - val_recall: 0.2387 - val_auc: 0.4284 - val_top 2 accuracy: 0.7044 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 6/30
# 6831/6831 [==============================] - 415s 61ms/step - loss: 0.0477 - accuracy: 0.9826 - precision: 0.9834 - recall: 0.9819 - auc: 0.9990 - top 2 accuracy: 0.9986 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 41.2609 - val_accuracy: 0.3738 - val_precision: 0.3738 - val_recall: 0.3738 - val_auc: 0.5304 - val_top 2 accuracy: 0.7295 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 7/30
# 6831/6831 [==============================] - 417s 61ms/step - loss: 0.0384 - accuracy: 0.9861 - precision: 0.9865 - recall: 0.9857 - auc: 0.9993 - top 2 accuracy: 0.9991 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 4.0390 - val_accuracy: 0.4389 - val_precision: 0.4395 - val_recall: 0.4358 - val_auc: 0.6112 - val_top 2 accuracy: 0.7942 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 8/30
# 6831/6831 [==============================] - 416s 61ms/step - loss: 0.0311 - accuracy: 0.9890 - precision: 0.9893 - recall: 0.9887 - auc: 0.9995 - top 2 accuracy: 0.9994 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 34.3382 - val_accuracy: 0.3744 - val_precision: 0.3744 - val_recall: 0.3744 - val_auc: 0.5308 - val_top 2 accuracy: 0.6648 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 9/30
# 6831/6831 [==============================] - 416s 61ms/step - loss: 0.0268 - accuracy: 0.9906 - precision: 0.9908 - recall: 0.9903 - auc: 0.9996 - top 2 accuracy: 0.9994 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 36.0357 - val_accuracy: 0.3739 - val_precision: 0.3739 - val_recall: 0.3739 - val_auc: 0.5304 - val_top 2 accuracy: 0.6070 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 10/30
# 6831/6831 [==============================] - 445s 65ms/step - loss: 0.0236 - accuracy: 0.9916 - precision: 0.9918 - recall: 0.9914 - auc: 0.9997 - top 2 accuracy: 0.9996 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 3.5209 - val_accuracy: 0.4606 - val_precision: 0.4617 - val_recall: 0.4564 - val_auc: 0.6334 - val_top 2 accuracy: 0.7919 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 11/30
# 6831/6831 [==============================] - 421s 62ms/step - loss: 0.0208 - accuracy: 0.9926 - precision: 0.9928 - recall: 0.9925 - auc: 0.9997 - top 2 accuracy: 0.9996 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 106.8123 - val_accuracy: 0.3738 - val_precision: 0.3738 - val_recall: 0.3738 - val_auc: 0.5303 - val_top 2 accuracy: 0.9640 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 12/30
# 6831/6831 [==============================] - 416s 61ms/step - loss: 0.0197 - accuracy: 0.9933 - precision: 0.9935 - recall: 0.9932 - auc: 0.9997 - top 2 accuracy: 0.9996 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 108.0162 - val_accuracy: 0.2225 - val_precision: 0.2225 - val_recall: 0.2225 - val_auc: 0.4169 - val_top 2 accuracy: 0.9421 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 13/30
# 6831/6831 [==============================] - 416s 61ms/step - loss: 0.0172 - accuracy: 0.9941 - precision: 0.9943 - recall: 0.9940 - auc: 0.9997 - top 2 accuracy: 0.9997 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 4.1905 - val_accuracy: 0.4305 - val_precision: 0.4313 - val_recall: 0.4277 - val_auc: 0.6004 - val_top 2 accuracy: 0.7787 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 14/30
# 6831/6831 [==============================] - 417s 61ms/step - loss: 0.0153 - accuracy: 0.9949 - precision: 0.9950 - recall: 0.9948 - auc: 0.9998 - top 2 accuracy: 0.9998 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 8.0138 - val_accuracy: 0.4391 - val_precision: 0.4398 - val_recall: 0.4381 - val_auc: 0.5986 - val_top 2 accuracy: 0.7614 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 15/30
# 6831/6831 [==============================] - 417s 61ms/step - loss: 0.0138 - accuracy: 0.9951 - precision: 0.9952 - recall: 0.9950 - auc: 0.9998 - top 2 accuracy: 0.9998 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 30.3604 - val_accuracy: 0.3744 - val_precision: 0.3743 - val_recall: 0.3743 - val_auc: 0.5310 - val_top 2 accuracy: 0.7294 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 16/30
# 6831/6831 [==============================] - 418s 61ms/step - loss: 0.0133 - accuracy: 0.9954 - precision: 0.9955 - recall: 0.9953 - auc: 0.9998 - top 2 accuracy: 0.9998 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 4.6364 - val_accuracy: 0.4296 - val_precision: 0.4296 - val_recall: 0.4272 - val_auc: 0.6032 - val_top 2 accuracy: 0.8094 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 17/30
# 6831/6831 [==============================] - 417s 61ms/step - loss: 0.0121 - accuracy: 0.9960 - precision: 0.9961 - recall: 0.9960 - auc: 0.9998 - top 2 accuracy: 0.9998 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 5.3822 - val_accuracy: 0.3883 - val_precision: 0.3888 - val_recall: 0.3861 - val_auc: 0.5566 - val_top 2 accuracy: 0.7440 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 18/30
# 6831/6831 [==============================] - 418s 61ms/step - loss: 0.0107 - accuracy: 0.9962 - precision: 0.9963 - recall: 0.9961 - auc: 0.9998 - top 2 accuracy: 0.9998 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 4.6667 - val_accuracy: 0.4255 - val_precision: 0.4261 - val_recall: 0.4232 - val_auc: 0.5995 - val_top 2 accuracy: 0.7857 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 19/30
# 6831/6831 [==============================] - 417s 61ms/step - loss: 0.0116 - accuracy: 0.9960 - precision: 0.9960 - recall: 0.9959 - auc: 0.9998 - top 2 accuracy: 0.9998 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 48.7348 - val_accuracy: 0.3741 - val_precision: 0.3741 - val_recall: 0.3741 - val_auc: 0.5307 - val_top 2 accuracy: 0.7153 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 20/30
# 6831/6831 [==============================] - 417s 61ms/step - loss: 0.0106 - accuracy: 0.9965 - precision: 0.9966 - recall: 0.9964 - auc: 0.9998 - top 2 accuracy: 0.9999 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 7.9978 - val_accuracy: 0.4623 - val_precision: 0.4635 - val_recall: 0.4607 - val_auc: 0.6189 - val_top 2 accuracy: 0.7796 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 21/30
# 6831/6831 [==============================] - 416s 61ms/step - loss: 0.0096 - accuracy: 0.9968 - precision: 0.9968 - recall: 0.9967 - auc: 0.9998 - top 2 accuracy: 0.9999 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 5.3260 - val_accuracy: 0.4217 - val_precision: 0.4224 - val_recall: 0.4201 - val_auc: 0.5935 - val_top 2 accuracy: 0.7994 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 22/30
# 6831/6831 [==============================] - 416s 61ms/step - loss: 0.0098 - accuracy: 0.9968 - precision: 0.9969 - recall: 0.9968 - auc: 0.9998 - top 2 accuracy: 0.9999 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 4.7726 - val_accuracy: 0.4248 - val_precision: 0.4253 - val_recall: 0.4223 - val_auc: 0.5923 - val_top 2 accuracy: 0.7486 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 23/30
# 6831/6831 [==============================] - 417s 61ms/step - loss: 0.0090 - accuracy: 0.9969 - precision: 0.9970 - recall: 0.9968 - auc: 0.9999 - top 2 accuracy: 0.9999 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 4.6107 - val_accuracy: 0.4415 - val_precision: 0.4424 - val_recall: 0.4386 - val_auc: 0.6057 - val_top 2 accuracy: 0.7815 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 24/30
# 6831/6831 [==============================] - 414s 61ms/step - loss: 0.0081 - accuracy: 0.9971 - precision: 0.9972 - recall: 0.9971 - auc: 0.9999 - top 2 accuracy: 0.9999 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 37.3981 - val_accuracy: 0.3765 - val_precision: 0.3765 - val_recall: 0.3765 - val_auc: 0.5335 - val_top 2 accuracy: 0.7844 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 25/30
# 6831/6831 [==============================] - 415s 61ms/step - loss: 0.0085 - accuracy: 0.9971 - precision: 0.9972 - recall: 0.9971 - auc: 0.9999 - top 2 accuracy: 0.9999 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 83.7954 - val_accuracy: 0.2225 - val_precision: 0.2225 - val_recall: 0.2225 - val_auc: 0.4169 - val_top 2 accuracy: 0.8514 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 26/30
# 6831/6831 [==============================] - 432s 63ms/step - loss: 0.0072 - accuracy: 0.9976 - precision: 0.9976 - recall: 0.9975 - auc: 0.9999 - top 2 accuracy: 0.9999 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 10.4848 - val_accuracy: 0.4319 - val_precision: 0.4321 - val_recall: 0.4313 - val_auc: 0.5909 - val_top 2 accuracy: 0.7818 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 27/30
# 6831/6831 [==============================] - 425s 62ms/step - loss: 0.0081 - accuracy: 0.9973 - precision: 0.9973 - recall: 0.9972 - auc: 0.9999 - top 2 accuracy: 0.9999 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 4.5943 - val_accuracy: 0.4462 - val_precision: 0.4476 - val_recall: 0.4444 - val_auc: 0.6149 - val_top 2 accuracy: 0.7815 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 28/30
# 6831/6831 [==============================] - 413s 60ms/step - loss: 0.0066 - accuracy: 0.9978 - precision: 0.9978 - recall: 0.9978 - auc: 0.9999 - top 2 accuracy: 1.0000 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 6.0663 - val_accuracy: 0.4851 - val_precision: 0.4863 - val_recall: 0.4839 - val_auc: 0.6397 - val_top 2 accuracy: 0.8033 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 29/30
# 6831/6831 [==============================] - 402s 59ms/step - loss: 0.0067 - accuracy: 0.9977 - precision: 0.9977 - recall: 0.9976 - auc: 0.9999 - top 2 accuracy: 0.9999 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 72.2654 - val_accuracy: 0.3739 - val_precision: 0.3739 - val_recall: 0.3739 - val_auc: 0.5303 - val_top 2 accuracy: 0.8523 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010
# Epoch 30/30
# 6831/6831 [==============================] - 419s 61ms/step - loss: 0.0068 - accuracy: 0.9978 - precision: 0.9978 - recall: 0.9977 - auc: 0.9999 - top 2 accuracy: 0.9999 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000 - val_loss: 50.8411 - val_accuracy: 0.2253 - val_precision: 0.2252 - val_recall: 0.2251 - val_auc: 0.4189 - val_top 2 accuracy: 0.7099 - val_top 3 accuracy: 1.0000 - val_top 5 accuracy: 1.0000 - lr: 0.0010

# %%
arch_name = 'bs_{}'.format(batch_size)

continue_model_path = '..\\models\\best_model_covidnet_no_balance\\' + '{}_{}_{}_eps.h5'.format(version, arch_name, epochs)
ft_resnet.save(continue_model_path)
np.save(f'..\\models\\best_model_covidnet_no_balance\\{version}_{arch_name}_{epochs}_eps.npy',
        history_dcnn.history)

# %%
import pickle 
ft_resnet.save_weights('..\\models\\best_model_covidnet_no_balance\\' + '{}_{}_{}_eps_wheights_only.h5'.format(version, arch_name, epochs))
symbolic_weights = getattr(ft_resnet.optimizer, 'weights')
weight_values = K.batch_get_value(symbolic_weights)
with open('..\\models\\best_model_covidnet_no_balance\\' + '{}_{}_{}_eps_optimizer.pkl'.format(version, arch_name, epochs), 'wb') as f:
    pickle.dump(weight_values, f)

# %%
# Visualization of the learning curves

# Loss
plt.subplot(1, 2, 1)
plt.plot(history_dcnn.history['loss'])
plt.plot(history_dcnn.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['train', 'validation'])

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(history_dcnn.history['accuracy'])
plt.plot(history_dcnn.history['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'validation'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 5
#       1 # Visualization of the learning curves
#       2
#       3 # Loss
#       4 plt.subplot(1, 2, 1)
# ----> 5 plt.plot(history_dcnn.history['loss'])
#       6 plt.plot(history_dcnn.history['val_loss'])
#       7 plt.xlabel('Epoch')
#
# NameError: name 'history_dcnn' is not defined

# %% [markdown]
# # Continue training

# %%
os.chdir(Path(str(Path(os.getcwd()).parent.absolute()) + '\\scripts\\3_Resnet18_first'))

# %%
os.getcwd()
# Out:
# 'd:\\Projects\\ADNI-brain-MRI-alzheimer-classification-and-GAN-generation\\scripts\\3_Resnet18_first'

# %%
METRICS = [ 
      keras.metrics.CategoricalAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.TopKCategoricalAccuracy(name='top 2 accuracy', k=2),
      keras.metrics.TopKCategoricalAccuracy(name='top 3 accuracy', k=3),
      keras.metrics.TopKCategoricalAccuracy(name='top 5 accuracy', k=5)
]

# %%
early_stopper = keras.callbacks.EarlyStopping(monitor='val_loss', patience=100)

# %%
tb = TensorBoard(log_dir =os.getcwd() + '\\gan_over\\logs_gan_over', write_graph = True)

lr_reducer = ReduceLROnPlateau(monitor='loss', factor=np.sqrt(0.1), patience=10, cooldown=0, min_lr=1e-5)

model_chkp = ModelCheckpoint(filepath=os.getcwd() + '\\covidnet_no_balance\\best_model_gan_over',
                            # monitor='val_quadratic_kappa_score',
                            monitor='val_accuracy',
                            save_best_only=True, save_weights_only=True, mode='max')

#resnet = ResNet18()
#resnet = ResNet18(classes=3, input_shape=(160, 192))
resnet = ResNet18(classes=3)


#model = keras.applications.resnet50.ResNet50(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000)
#model.summary()

#resnet.layers.pop()
#for layer in resnet.layers:
#    layer.trainable = False

x = resnet.layers[-1].output

x = Dropout(0.25)(x)

x = Dense(3, activation = 'softmax')(x)


ft_resnet = Model(resnet.input, x)
ft_resnet.compile(optimizer = Adam(learning_rate = 0.001), loss = 'categorical_crossentropy', metrics = METRICS)

print("model loaded")

ft_resnet.summary()
# Out:
# <class 'keras.engine.keras_tensor.KerasTensor'>
# model loaded
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 192, 160, 1  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 198, 166, 1)  0           ['input_3[0][0]']
#
#  conv1 (Conv2D)                 (None, 96, 80, 64)   3200        ['conv1_pad[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 96, 80, 64)   256         ['conv1[0][0]']
#
#  leaky_re_lu_34 (LeakyReLU)     (None, 96, 80, 64)   0           ['bn_conv1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 47, 39, 64)  0           ['leaky_re_lu_34[0][0]']
#
#  res2a_branch2a (Conv2D)        (None, 47, 39, 64)   36928       ['max_pooling2d_2[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 47, 39, 64)  256         ['res2a_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_35 (LeakyReLU)     (None, 47, 39, 64)   0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv2D)        (None, 47, 39, 64)   36928       ['leaky_re_lu_35[0][0]']
#
#  res2a_branch1 (Conv2D)         (None, 47, 39, 64)   4160        ['max_pooling2d_2[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 47, 39, 64)  256         ['res2a_branch2b[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 47, 39, 64)  256         ['res2a_branch1[0][0]']
#  on)
#
#  add_16 (Add)                   (None, 47, 39, 64)   0           ['bn2a_branch2b[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  leaky_re_lu_36 (LeakyReLU)     (None, 47, 39, 64)   0           ['add_16[0][0]']
#
#  res2b_branch2a (Conv2D)        (None, 47, 39, 64)   36928       ['leaky_re_lu_36[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 47, 39, 64)  256         ['res2b_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_37 (LeakyReLU)     (None, 47, 39, 64)   0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv2D)        (None, 47, 39, 64)   36928       ['leaky_re_lu_37[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 47, 39, 64)  256         ['res2b_branch2b[0][0]']
#  ion)
#
#  add_17 (Add)                   (None, 47, 39, 64)   0           ['bn2b_branch2b[0][0]',
#                                                                   'leaky_re_lu_36[0][0]']
#
#  leaky_re_lu_38 (LeakyReLU)     (None, 47, 39, 64)   0           ['add_17[0][0]']
#
#  res3a_branch2a (Conv2D)        (None, 24, 20, 128)  73856       ['leaky_re_lu_38[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 24, 20, 128)  512        ['res3a_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_39 (LeakyReLU)     (None, 24, 20, 128)  0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv2D)        (None, 24, 20, 128)  147584      ['leaky_re_lu_39[0][0]']
#
#  res3a_branch1 (Conv2D)         (None, 24, 20, 128)  8320        ['leaky_re_lu_38[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 24, 20, 128)  512        ['res3a_branch2b[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 24, 20, 128)  512        ['res3a_branch1[0][0]']
#  on)
#
#  add_18 (Add)                   (None, 24, 20, 128)  0           ['bn3a_branch2b[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  leaky_re_lu_40 (LeakyReLU)     (None, 24, 20, 128)  0           ['add_18[0][0]']
#
#  res3b_branch2a (Conv2D)        (None, 24, 20, 128)  147584      ['leaky_re_lu_40[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 24, 20, 128)  512        ['res3b_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_41 (LeakyReLU)     (None, 24, 20, 128)  0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv2D)        (None, 24, 20, 128)  147584      ['leaky_re_lu_41[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 24, 20, 128)  512        ['res3b_branch2b[0][0]']
#  ion)
#
#  add_19 (Add)                   (None, 24, 20, 128)  0           ['bn3b_branch2b[0][0]',
#                                                                   'leaky_re_lu_40[0][0]']
#
#  leaky_re_lu_42 (LeakyReLU)     (None, 24, 20, 128)  0           ['add_19[0][0]']
#
#  res4a_branch2a (Conv2D)        (None, 12, 10, 256)  295168      ['leaky_re_lu_42[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 12, 10, 256)  1024       ['res4a_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_43 (LeakyReLU)     (None, 12, 10, 256)  0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv2D)        (None, 12, 10, 256)  590080      ['leaky_re_lu_43[0][0]']
#
#  res4a_branch1 (Conv2D)         (None, 12, 10, 256)  33024       ['leaky_re_lu_42[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 12, 10, 256)  1024       ['res4a_branch2b[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 12, 10, 256)  1024       ['res4a_branch1[0][0]']
#  on)
#
#  add_20 (Add)                   (None, 12, 10, 256)  0           ['bn4a_branch2b[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  leaky_re_lu_44 (LeakyReLU)     (None, 12, 10, 256)  0           ['add_20[0][0]']
#
#  res4b_branch2a (Conv2D)        (None, 12, 10, 256)  590080      ['leaky_re_lu_44[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 12, 10, 256)  1024       ['res4b_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_45 (LeakyReLU)     (None, 12, 10, 256)  0           ['bn4b_branch2a[0][0]']
#
#  res4b_branch2b (Conv2D)        (None, 12, 10, 256)  590080      ['leaky_re_lu_45[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 12, 10, 256)  1024       ['res4b_branch2b[0][0]']
#  ion)
#
#  add_21 (Add)                   (None, 12, 10, 256)  0           ['bn4b_branch2b[0][0]',
#                                                                   'leaky_re_lu_44[0][0]']
#
#  leaky_re_lu_46 (LeakyReLU)     (None, 12, 10, 256)  0           ['add_21[0][0]']
#
#  res5a_branch2a (Conv2D)        (None, 6, 5, 512)    1180160     ['leaky_re_lu_46[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 6, 5, 512)   2048        ['res5a_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_47 (LeakyReLU)     (None, 6, 5, 512)    0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv2D)        (None, 6, 5, 512)    2359808     ['leaky_re_lu_47[0][0]']
#
#  res5a_branch1 (Conv2D)         (None, 6, 5, 512)    131584      ['leaky_re_lu_46[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 6, 5, 512)   2048        ['res5a_branch2b[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 6, 5, 512)   2048        ['res5a_branch1[0][0]']
#  on)
#
#  add_22 (Add)                   (None, 6, 5, 512)    0           ['bn5a_branch2b[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  leaky_re_lu_48 (LeakyReLU)     (None, 6, 5, 512)    0           ['add_22[0][0]']
#
#  res5b_branch2a (Conv2D)        (None, 6, 5, 512)    2359808     ['leaky_re_lu_48[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 6, 5, 512)   2048        ['res5b_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_49 (LeakyReLU)     (None, 6, 5, 512)    0           ['bn5b_branch2a[0][0]']
#
#  res5b_branch2b (Conv2D)        (None, 6, 5, 512)    2359808     ['leaky_re_lu_49[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 6, 5, 512)   2048        ['res5b_branch2b[0][0]']
#  ion)
#
#  add_23 (Add)                   (None, 6, 5, 512)    0           ['bn5b_branch2b[0][0]',
#                                                                   'leaky_re_lu_48[0][0]']
#
#  leaky_re_lu_50 (LeakyReLU)     (None, 6, 5, 512)    0           ['add_23[0][0]']
#
#  avg_pool (AveragePooling2D)    (None, 1, 1, 512)    0           ['leaky_re_lu_50[0][0]']
#
#  flatten_2 (Flatten)            (None, 512)          0           ['avg_pool[0][0]']
#
#  dropout_2 (Dropout)            (None, 512)          0           ['flatten_2[0][0]']
#
#  dense_2 (Dense)                (None, 3)            1539        ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 11,190,595
# Trainable params: 11,180,867
# Non-trainable params: 9,728
# __________________________________________________________________________________________________

# %% [markdown]
# Changing back the folder to data path

# %%
os.chdir(Path(str(Path(os.getcwd()).parent.absolute().parent.absolute()) + '\\adni-images-Full-resized160x192'))
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 os.chdir(Path(str(Path(os.getcwd()).parent.absolute().parent.absolute()) + '\\adni-images-Full-resized160x192'))
#       2 os.getcwd()
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'd:\\Projects\\adni-images-Full-resized160x192'

# %%
print(train_tot, valid_tot)

train_steps = np.ceil(train_tot/batch_size)
valid_steps = np.ceil(valid_tot/batch_size)

print (train_steps, valid_steps)
# Out:
# 218575 18024
# 6831.0 564.0

# %%
import pickle 
import tensorflow

ft_resnet = tensorflow.keras.models.load_model('..\\models\\best_model_gan_over\\' + '{}_{}_{}_eps.h5'.format(version, arch_name, epochs))
old_weights = ft_resnet.optimizier.get_weights()

ft_resnet._make_train_function()
with open('..\\models\\best_model_gan_over\\' + '{}_{}_{}_eps_optimizer.pkl'.format(version, arch_name, epochs), 'rb') as f:
    weight_values = pickle.load(f)
ft_resnet.optimizer.set_weights(weight_values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 5
#       2 import tensorflow
#       4 ft_resnet = tensorflow.keras.models.load_model('..\\models\\best_model_gan_over\\' + '{}_{}_{}_eps.h5'.format(version, arch_name, epochs))
# ----> 5 old_weights = ft_resnet.optimizier.get_weights()
#       7 ft_resnet._make_train_function()
#       8 with open('..\\models\\best_model_gan_over\\' + '{}_{}_{}_eps_optimizer.pkl'.format(version, arch_name, epochs), 'rb') as f:
#
# AttributeError: 'Functional' object has no attribute 'optimizier'

# %%
import pickle 

ft_resnet.load_weights('..\\models\\best_model_gan_over\\' + '{}_{}_{}_eps.h5'.format(version, arch_name, epochs))
ft_resnet.make_train_function()
with open('..\\models\\best_model_gan_over\\' + '{}_{}_{}_eps_optimizer.pkl'.format(version, arch_name, epochs), 'rb') as f:
    weight_values = pickle.load(f)
ft_resnet.optimizer.set_weights(weight_values)

#fit_generator
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 3
#       1 import pickle
# ----> 3 ft_resnet.load_model('..\\models\\best_model_gan_over\\' + '{}_{}_{}_eps.h5'.format(version, arch_name, epochs))
#       4 ft_resnet.make_train_function()
#       5 with open('..\\models\\best_model_gan_over\\' + '{}_{}_{}_eps_optimizer.pkl'.format(version, arch_name, epochs), 'rb') as f:
#
# AttributeError: 'Functional' object has no attribute 'load_model'

# %%
version = "v2"
epochs = 30

# %%
history_dcnn = ft_resnet.fit(train_data, 
                             steps_per_epoch=train_steps,
                             epochs=epochs,
                             workers = 4,
                             callbacks = [tb, model_chkp, lr_reducer, early_stopper],
                             validation_data = validation_data, 
                             validation_steps = valid_steps)

# %%
arch_name = 'bs_{}'.format(batch_size)

continue_model_path = '..\\models\\best_model_gan_over\\' + '{}_{}_{}_eps.h5'.format(version, arch_name, epochs)
ft_resnet.save(continue_model_path)
np.save(f'..\\models\\best_model_gan_over\\{version}_{arch_name}_{epochs}_eps.npy',
        history_dcnn.history)

# %%
import pickle 
ft_resnet.save_weights('..\\models\\best_model_gan_over\\' + '{}_{}_{}_eps_wheights_only.h5'.format(version, arch_name, epochs))
symbolic_weights = getattr(ft_resnet.optimizer, 'weights')
weight_values = K.batch_get_value(symbolic_weights)
with open('..\\models\\best_model_gan_over\\' + '{}_{}_{}_eps_optimizer.pkl'.format(version, arch_name, epochs), 'wb') as f:
    pickle.dump(weight_values, f)

# %% [markdown]
# # Load Model

# %%
os.getcwd()
# Out:
# 'd:\\Projects\\ADNI-brain-MRI-alzheimer-classification-and-GAN-generation\\adni-images-Full-resized160x192'

# %%
# Load model
net_dcnn = keras.models.load_model("..\\models\\best_model_covidnet_no_balance\\v1_bs_32_30_eps.h5")

# %%
# Load hystory and convert to dict
history = np.load('..\\models\\best_model_covidnet_no_balance\\v1_bs_32_30_eps.npy', allow_pickle=True).item()

# %% [markdown]
# # Model Evaluation

# %%
# Set visualization size for figures 
plt.rcParams['figure.figsize'] = [5,5] # width, height

# %%
CATEGORIES = "ad", "mci","nor"

# %%
history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'recall', 'auc', 'top 2 accuracy', 'top 3 accuracy', 'top 5 accuracy', 'val_loss', 'val_accuracy', 'val_precision', 'val_recall', 'val_auc', 'val_top 2 accuracy', 'val_top 3 accuracy', 'val_top 5 accuracy', 'lr'])

# %%
test_data = validation_data

# %%
history['accuracy'][:1+1]
# Out:
# [0.5128205418586731, 0.6809400916099548]

# %%
# %matplotlib inline

def print_graph(item, index, history):
    plt.figure()
    train_values = history[item][:index+5]
    plt.plot(train_values)
    test_values = history['val_' + item][:index+5]
    plt.plot(test_values)
    plt.legend(['training','validation'])
    plt.title('Training and validation '+ item)
    plt.xlabel('epoch')
    plt.show()
    plot = '{}.png'.format(item)
    plt.savefig(plot)

# %%
def test_set_results(pred_value, n=1):    
    y_test = test_data.labels
    X_test, _ = test_data.next()
    
    corr_pred = confusion_matrix(y_test, pred_value)
    fig=plt.figure(figsize=(10, 8))
    ax = plt.axes()
    
    sns.heatmap(corr_pred,annot=True, fmt="d",cmap="Purples", xticklabels=CATEGORIES, yticklabels=CATEGORIES)
    ax.set_title('Confusione Matrix')
    plt.show()
    
    n_correct = int(corr_pred[0][0] + corr_pred[1][1] + corr_pred[2][2])
    print('...'*15)

    print('> Correct Predictions:', n_correct)
    
    n_wrongs = len(y_test) - n_correct
    print('> Wrong Predictions:', n_wrongs)
    print('...'*15)
    
    print(classification_report(test_data.labels, pred_value, target_names=CATEGORIES))

# %%
def printResults(name, model):
    predictions = model.predict(test_data, verbose=1)
    preds = np.argmax(predictions, axis=1)
    test_set_results(preds)

# %%
def model_summary(model, history, name):
    val_acc = history['val_accuracy'] #validation accuracy history
    index= val_acc.index(max(val_acc))
    print('Best Epochs:', index)


    test_loss, test_accuracy, test_precision, test_recall, auc, _, _, _ = model.evaluate(test_data, verbose=1)

    train_accuracy = history['accuracy'][index]
    train_loss = history['loss'][index]

    print_graph('loss', index, history)
    print_graph('accuracy', index, history)

    print('---'*15) 
    print(name)
    print('> Accuracy on train:',round(train_accuracy, 2), 
            '\tLoss on train:', round(train_loss,2))
    

    print('> Accuracy on test:',round(test_accuracy, 2),
            '\tLoss on test:',round(test_loss,2))

    print('---'*15)
    print('> predicting test')
    print('---'*15)

    printResults(name, model)

# %%
model_summary(net_dcnn, history, 'DCCN - Random Undersampling')
# Out:
# Best Epochs: 27
# 564/564 [==============================] - 29s 42ms/step - loss: 50.8403 - accuracy: 0.2253 - precision: 0.2252 - recall: 0.2251 - auc: 0.4189 - top 2 accuracy: 0.7100 - top 3 accuracy: 1.0000 - top 5 accuracy: 1.0000
# ---------------------------------------------
# DCCN - Random Undersampling
# > Accuracy on train: 1.0 	Loss on train: 0.01
# > Accuracy on test: 0.23 	Loss on test: 50.84
# ---------------------------------------------
# > predicting test
# ---------------------------------------------
# 564/564 [==============================] - 23s 40ms/step
# .............................................
# > Correct Predictions: 4038
# > Wrong Predictions: 13986
# .............................................
#               precision    recall  f1-score   support
#
#           ad       0.22      0.99      0.36      4011
#          mci       0.40      0.01      0.02      7276
#          nor       0.25      0.00      0.00      6737
#
#     accuracy                           0.22     18024
#    macro avg       0.29      0.33      0.13     18024
# weighted avg       0.31      0.22      0.09     18024
