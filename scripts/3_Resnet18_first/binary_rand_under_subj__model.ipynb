# %% [markdown]
# **Importing libraries**

# %%
# Keras e TF

#import tensorflow
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, Conv1D, MaxPooling2D, Dense, Flatten, BatchNormalization, Activation, AveragePooling2D, Input, Flatten, Dropout
from keras.callbacks import ModelCheckpoint

# Sk-Learn
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix, ConfusionMatrixDisplay, roc_curve, roc_auc_score, RocCurveDisplay, accuracy_score, classification_report, confusion_matrix

# Base
import os 
from pathlib import Path
from matplotlib import pyplot as plt
import seaborn as sns # 
import numpy as np #
import pandas as pd # 

from keras.utils import load_img

import pydot
import pydotplus
from pydotplus import graphviz

from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import backend as K
from custom_resnet import ResNet18


from keras.models import Model
from keras.optimizers import Adam

# %%
keras.__version__
# Out:
# '2.10.0'

# %% [markdown]
# **Setting path to the dataset**

# %%
os.chdir(Path(str(Path(os.getcwd()).parent.absolute().parent.absolute()) +
              '\\adni-images-Full-resized160x192-binary'))

# %%
print(os.getcwd())
# Out:
# d:\Projects\ADNI-brain-MRI-alzheimer-classification-and-GAN-generation\adni-images-Full-resized160x192-binary

# %% [markdown]
# # Loading Dataset

# %%
data_dir = Path(os.getcwd())

def data_mean_std():
    names = []
    for root, dirs, files in os.walk(data_dir):
        if "train" in root:
            for file in files:
                names.append(root + '/' + file)
    
    print(len(names))
                
    array = []
    for name in names:
        try:
            img = load_img(name, color_mode = 'grayscale', target_size = (160, 192))
            img_array = np.asarray(img)
            array.append(img_array)
        except:
            print("Name: ", name)
            continue
    
    print(img_array.shape) # Correct amount of images

    array = np.asarray(array)
    print(array.shape)
    print(array.mean().shape, array.std().shape)
    return array.mean(), array.std()
""" 
stats_file = open(stats_path, 'r')
stats_lst = stats_file.read().split('\n')
mean = float(stats_lst[0])
std = float(stats_lst[1])"""
mean, std = data_mean_std()

print(mean, std)
# Out:
# 61829
# Name:  d:\Projects\ADNI-brain-MRI-alzheimer-classification-and-GAN-generation\adni-images-Full-resized160x192-binary\no_balance_binary\logs_no_balance_binary\train/events.out.tfevents.1686073730.GIORGIO-LAPTOP.43900.0.v2
# Name:  d:\Projects\ADNI-brain-MRI-alzheimer-classification-and-GAN-generation\adni-images-Full-resized160x192-binary\train\ad/ADNI_021_S_0753_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20071115091031185_S18712_I82162_101.png

# %% [markdown]
# Use the pre-computed values (oversampling GAN):

# %%
mean = 35.80925715423529
std = 45.16736479384096

# %%
def normalize(x):
    return (x - mean) / std

# %%
batch_size = 32 # Batch size

train_path = './train_rand_sub_under'
test_path = './test'
valid_path = './valid'
#rescale = 1./255.
train_datagen = ImageDataGenerator(preprocessing_function = normalize)
test_datagen = ImageDataGenerator(preprocessing_function = normalize)
valid_datagen = ImageDataGenerator(preprocessing_function = normalize)

# %%
train_data = train_datagen.flow_from_directory(
        train_path,
        color_mode = 'grayscale',
        target_size=(192, 160),  # Lo inserisco per precauzione
        batch_size=batch_size,
        seed=123,
        shuffle=True,
        class_mode= "binary")
# Out:
# Found 40687 images belonging to 2 classes.

# %%
validation_data = valid_datagen.flow_from_directory(
        valid_path,
        classes={'ad': 0, 
                'nor': 1},
        color_mode='grayscale',
        target_size=(192, 160),  # Lo inserisco per precauzione
        batch_size=batch_size,
        seed=123,
        shuffle=True,
        class_mode= "binary")
# Out:
# Found 10748 images belonging to 2 classes.

# %%
# Test set
test_data = test_datagen.flow_from_directory(
        test_path,
        color_mode='grayscale',
        target_size=(192, 160),  # Lo inserisco per precauzione
        batch_size=batch_size,
        shuffle=False,
        class_mode= "binary")
# Out:
# Found 4572 images belonging to 2 classes.

# %%
train_data.class_indices
# Out:
# {'ad': 0, 'nor': 1}

# %%
validation_data.class_indices
# Out:
# {'ad': 0, 'nor': 1}

# %%
test_data.class_indices
# Out:
# {'ad': 0, 'nor': 1}

# %%
train_ad = len(os.listdir(os.getcwd() + '\\train_rand_sub_under\\ad'))
train_nor = len(os.listdir(os.getcwd() + '\\train_rand_sub_under\\nor'))
train_tot = train_ad + train_nor
print(train_ad/train_tot, train_nor/train_tot)
# Out:
# 0.42190380219726203 0.578096197802738

# %%
test_ad = len(os.listdir(os.getcwd() + '\\test\\ad'))
test_nor = len(os.listdir(os.getcwd() + '\\test\\nor'))
test_tot = test_ad + test_nor
print(test_ad/test_tot, test_nor/test_tot)
# Out:
# 0.5201224846894138 0.4798775153105862

# %%
valid_ad = len(os.listdir(os.getcwd() + '\\valid\\ad'))
valid_nor = len(os.listdir(os.getcwd() + '\\valid\\nor'))
valid_tot = valid_ad + valid_nor
print(valid_ad/valid_tot, valid_nor/valid_tot)
# Out:
# 0.3731857089691105 0.6268142910308895

# %% [markdown]
# # Model Definition

# %% [markdown]
# Changing the folder to data path to save weights into

# %%
os.chdir(Path(str(Path(os.getcwd()).parent.absolute()) + '\\scripts\\3_Resnet18_first'))

# %%
os.getcwd()
# Out:
# 'd:\\Projects\\ADNI-brain-MRI-alzheimer-classification-and-GAN-generation\\scripts\\3_Resnet18_first'

# %%
METRICS = [ 
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'),
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc')
]

# %%
early_stopper = keras.callbacks.EarlyStopping(monitor='val_loss', patience=100)

# %%
version = "v1"
epochs = 50
arch_name = 'bs_{}'.format(batch_size)

tb = TensorBoard(log_dir =os.getcwd() + '\\binary_rand_sub_under\\logs_binary_rand_sub_under', write_graph = True)

lr_reducer = ReduceLROnPlateau(monitor='loss', factor=np.sqrt(0.1), patience=10, cooldown=0, min_lr=1e-5)

model_chkp = ModelCheckpoint(filepath='D:\\Projects\\ADNI-brain-MRI-alzheimer-classification-and-GAN-generation\\models\\best_model_binary_rand_sub_under\\{}_{}_{}_eps_best.hdf5'.format(version, arch_name, epochs),
                            # monitor='val_quadratic_kappa_score',
                            monitor='val_accuracy',
                            save_best_only=True, save_weights_only=True, mode='max')

#resnet = ResNet18()
#resnet = ResNet18(classes=3, input_shape=(160, 192))
resnet = ResNet18(classes=2)


#model = keras.applications.resnet50.ResNet50(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000)
#model.summary()

#resnet.layers.pop()
#for layer in resnet.layers:
#    layer.trainable = False

x = resnet.layers[-1].output

# x = Dropout(0.25)(x)

x = Dense(1, activation = 'sigmoid')(x)


ft_resnet = Model(resnet.input, x)
optimizer = Adam(learning_rate = 0.001)
ft_resnet.compile(optimizer = optimizer, loss = 'BinaryCrossentropy', metrics = METRICS)

print("model loaded")

ft_resnet.summary()
# Out:
# <class 'keras.engine.keras_tensor.KerasTensor'>
# model loaded
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 192, 160, 1  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 198, 166, 1)  0           ['input_1[0][0]']
#
#  conv1 (Conv2D)                 (None, 96, 80, 64)   3200        ['conv1_pad[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 96, 80, 64)   256         ['conv1[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 96, 80, 64)   0           ['bn_conv1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 47, 39, 64)   0           ['leaky_re_lu[0][0]']
#
#  res2a_branch2a (Conv2D)        (None, 47, 39, 64)   36928       ['max_pooling2d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 47, 39, 64)  256         ['res2a_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 47, 39, 64)   0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv2D)        (None, 47, 39, 64)   36928       ['leaky_re_lu_1[0][0]']
#
#  res2a_branch1 (Conv2D)         (None, 47, 39, 64)   4160        ['max_pooling2d[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 47, 39, 64)  256         ['res2a_branch2b[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 47, 39, 64)  256         ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 47, 39, 64)   0           ['bn2a_branch2b[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 47, 39, 64)   0           ['add[0][0]']
#
#  res2b_branch2a (Conv2D)        (None, 47, 39, 64)   36928       ['leaky_re_lu_2[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 47, 39, 64)  256         ['res2b_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 47, 39, 64)   0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv2D)        (None, 47, 39, 64)   36928       ['leaky_re_lu_3[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 47, 39, 64)  256         ['res2b_branch2b[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 47, 39, 64)   0           ['bn2b_branch2b[0][0]',
#                                                                   'leaky_re_lu_2[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 47, 39, 64)   0           ['add_1[0][0]']
#
#  res3a_branch2a (Conv2D)        (None, 24, 20, 128)  73856       ['leaky_re_lu_4[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 24, 20, 128)  512        ['res3a_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 24, 20, 128)  0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv2D)        (None, 24, 20, 128)  147584      ['leaky_re_lu_5[0][0]']
#
#  res3a_branch1 (Conv2D)         (None, 24, 20, 128)  8320        ['leaky_re_lu_4[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 24, 20, 128)  512        ['res3a_branch2b[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 24, 20, 128)  512        ['res3a_branch1[0][0]']
#  on)
#
#  add_2 (Add)                    (None, 24, 20, 128)  0           ['bn3a_branch2b[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 24, 20, 128)  0           ['add_2[0][0]']
#
#  res3b_branch2a (Conv2D)        (None, 24, 20, 128)  147584      ['leaky_re_lu_6[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 24, 20, 128)  512        ['res3b_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 24, 20, 128)  0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv2D)        (None, 24, 20, 128)  147584      ['leaky_re_lu_7[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 24, 20, 128)  512        ['res3b_branch2b[0][0]']
#  ion)
#
#  add_3 (Add)                    (None, 24, 20, 128)  0           ['bn3b_branch2b[0][0]',
#                                                                   'leaky_re_lu_6[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 24, 20, 128)  0           ['add_3[0][0]']
#
#  res4a_branch2a (Conv2D)        (None, 12, 10, 256)  295168      ['leaky_re_lu_8[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 12, 10, 256)  1024       ['res4a_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_9 (LeakyReLU)      (None, 12, 10, 256)  0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv2D)        (None, 12, 10, 256)  590080      ['leaky_re_lu_9[0][0]']
#
#  res4a_branch1 (Conv2D)         (None, 12, 10, 256)  33024       ['leaky_re_lu_8[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 12, 10, 256)  1024       ['res4a_branch2b[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 12, 10, 256)  1024       ['res4a_branch1[0][0]']
#  on)
#
#  add_4 (Add)                    (None, 12, 10, 256)  0           ['bn4a_branch2b[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 12, 10, 256)  0           ['add_4[0][0]']
#
#  res4b_branch2a (Conv2D)        (None, 12, 10, 256)  590080      ['leaky_re_lu_10[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 12, 10, 256)  1024       ['res4b_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_11 (LeakyReLU)     (None, 12, 10, 256)  0           ['bn4b_branch2a[0][0]']
#
#  res4b_branch2b (Conv2D)        (None, 12, 10, 256)  590080      ['leaky_re_lu_11[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 12, 10, 256)  1024       ['res4b_branch2b[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 12, 10, 256)  0           ['bn4b_branch2b[0][0]',
#                                                                   'leaky_re_lu_10[0][0]']
#
#  leaky_re_lu_12 (LeakyReLU)     (None, 12, 10, 256)  0           ['add_5[0][0]']
#
#  res5a_branch2a (Conv2D)        (None, 6, 5, 512)    1180160     ['leaky_re_lu_12[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 6, 5, 512)   2048        ['res5a_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_13 (LeakyReLU)     (None, 6, 5, 512)    0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv2D)        (None, 6, 5, 512)    2359808     ['leaky_re_lu_13[0][0]']
#
#  res5a_branch1 (Conv2D)         (None, 6, 5, 512)    131584      ['leaky_re_lu_12[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 6, 5, 512)   2048        ['res5a_branch2b[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 6, 5, 512)   2048        ['res5a_branch1[0][0]']
#  on)
#
#  add_6 (Add)                    (None, 6, 5, 512)    0           ['bn5a_branch2b[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  leaky_re_lu_14 (LeakyReLU)     (None, 6, 5, 512)    0           ['add_6[0][0]']
#
#  res5b_branch2a (Conv2D)        (None, 6, 5, 512)    2359808     ['leaky_re_lu_14[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 6, 5, 512)   2048        ['res5b_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_15 (LeakyReLU)     (None, 6, 5, 512)    0           ['bn5b_branch2a[0][0]']
#
#  res5b_branch2b (Conv2D)        (None, 6, 5, 512)    2359808     ['leaky_re_lu_15[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 6, 5, 512)   2048        ['res5b_branch2b[0][0]']
#  ion)
#
#  add_7 (Add)                    (None, 6, 5, 512)    0           ['bn5b_branch2b[0][0]',
#                                                                   'leaky_re_lu_14[0][0]']
#
#  leaky_re_lu_16 (LeakyReLU)     (None, 6, 5, 512)    0           ['add_7[0][0]']
#
#  avg_pool (AveragePooling2D)    (None, 1, 1, 512)    0           ['leaky_re_lu_16[0][0]']
#
#  flatten (Flatten)              (None, 512)          0           ['avg_pool[0][0]']
#
#  dense (Dense)                  (None, 1)            513         ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 11,189,569
# Trainable params: 11,179,841
# Non-trainable params: 9,728
# __________________________________________________________________________________________________

# %% [markdown]
# Changing back the folder to data path

# %%
os.chdir(Path(str(Path(os.getcwd()).parent.absolute().parent.absolute()) + '\\adni-images-Full-resized160x192-binary'))
os.getcwd()
# Out:
# 'd:\\Projects\\ADNI-brain-MRI-alzheimer-classification-and-GAN-generation\\adni-images-Full-resized160x192-binary'

# %%
print(train_tot, valid_tot)

train_steps = np.ceil(train_tot/batch_size)
valid_steps = np.ceil(valid_tot/batch_size)

print (train_steps, valid_steps)

#fit_generator

history_dcnn = ft_resnet.fit(train_data, 
                             steps_per_epoch=train_steps,
                             epochs=epochs,
                             workers = 4,
                             callbacks = [tb, model_chkp, lr_reducer, early_stopper],
                             validation_data = validation_data, 
                             validation_steps = valid_steps)
# Out:
# 40687 10748
# 1272.0 336.0
# Epoch 1/50
# 1272/1272 [==============================] - 93s 67ms/step - loss: 0.5060 - tp: 19063.0000 - fp: 5921.0000 - tn: 11245.0000 - fn: 4458.0000 - accuracy: 0.7449 - precision: 0.7630 - recall: 0.8105 - auc: 0.8250 - val_loss: 0.8134 - val_tp: 5610.0000 - val_fp: 2901.0000 - val_tn: 1110.0000 - val_fn: 1127.0000 - val_accuracy: 0.6252 - val_precision: 0.6591 - val_recall: 0.8327 - val_auc: 0.6197 - lr: 0.0010
# Epoch 2/50
# 1272/1272 [==============================] - 93s 73ms/step - loss: 0.2660 - tp: 21382.0000 - fp: 2476.0000 - tn: 14690.0000 - fn: 2139.0000 - accuracy: 0.8866 - precision: 0.8962 - recall: 0.9091 - auc: 0.9552 - val_loss: 1.7130 - val_tp: 3403.0000 - val_fp: 1537.0000 - val_tn: 2474.0000 - val_fn: 3334.0000 - val_accuracy: 0.5468 - val_precision: 0.6889 - val_recall: 0.5051 - val_auc: 0.5948 - lr: 0.0010
# Epoch 3/50
# 1272/1272 [==============================] - 113s 89ms/step - loss: 0.1487 - tp: 22376.0000 - fp: 1320.0000 - tn: 15846.0000 - fn: 1145.0000 - accuracy: 0.9394 - precision: 0.9443 - recall: 0.9513 - auc: 0.9858 - val_loss: 2.4443 - val_tp: 1383.0000 - val_fp: 550.0000 - val_tn: 3461.0000 - val_fn: 5354.0000 - val_accuracy: 0.4507 - val_precision: 0.7155 - val_recall: 0.2053 - val_auc: 0.5815 - lr: 0.0010
# Epoch 4/50
# 1272/1272 [==============================] - 98s 77ms/step - loss: 0.0969 - tp: 22790.0000 - fp: 806.0000 - tn: 16360.0000 - fn: 731.0000 - accuracy: 0.9622 - precision: 0.9658 - recall: 0.9689 - auc: 0.9937 - val_loss: 1.4378 - val_tp: 5190.0000 - val_fp: 2258.0000 - val_tn: 1753.0000 - val_fn: 1547.0000 - val_accuracy: 0.6460 - val_precision: 0.6968 - val_recall: 0.7704 - val_auc: 0.6495 - lr: 0.0010
# Epoch 5/50
# 1272/1272 [==============================] - 97s 76ms/step - loss: 0.0710 - tp: 23021.0000 - fp: 571.0000 - tn: 16595.0000 - fn: 500.0000 - accuracy: 0.9737 - precision: 0.9758 - recall: 0.9787 - auc: 0.9962 - val_loss: 3.2148 - val_tp: 2205.0000 - val_fp: 1404.0000 - val_tn: 2607.0000 - val_fn: 4532.0000 - val_accuracy: 0.4477 - val_precision: 0.6110 - val_recall: 0.3273 - val_auc: 0.5197 - lr: 0.0010
# Epoch 6/50
# 1272/1272 [==============================] - 97s 76ms/step - loss: 0.0597 - tp: 23095.0000 - fp: 457.0000 - tn: 16709.0000 - fn: 426.0000 - accuracy: 0.9783 - precision: 0.9806 - recall: 0.9819 - auc: 0.9974 - val_loss: 2.1299 - val_tp: 3108.0000 - val_fp: 1316.0000 - val_tn: 2695.0000 - val_fn: 3629.0000 - val_accuracy: 0.5399 - val_precision: 0.7025 - val_recall: 0.4613 - val_auc: 0.5954 - lr: 0.0010
# Epoch 7/50
# 1272/1272 [==============================] - 97s 76ms/step - loss: 0.0443 - tp: 23176.0000 - fp: 357.0000 - tn: 16809.0000 - fn: 345.0000 - accuracy: 0.9827 - precision: 0.9848 - recall: 0.9853 - auc: 0.9986 - val_loss: 2.3259 - val_tp: 3819.0000 - val_fp: 1691.0000 - val_tn: 2320.0000 - val_fn: 2918.0000 - val_accuracy: 0.5712 - val_precision: 0.6931 - val_recall: 0.5669 - val_auc: 0.6025 - lr: 0.0010
# Epoch 8/50
# 1272/1272 [==============================] - 97s 76ms/step - loss: 0.0409 - tp: 23236.0000 - fp: 292.0000 - tn: 16874.0000 - fn: 285.0000 - accuracy: 0.9858 - precision: 0.9876 - recall: 0.9879 - auc: 0.9984 - val_loss: 1.9691 - val_tp: 3929.0000 - val_fp: 1645.0000 - val_tn: 2366.0000 - val_fn: 2808.0000 - val_accuracy: 0.5857 - val_precision: 0.7049 - val_recall: 0.5832 - val_auc: 0.6228 - lr: 0.0010
# Epoch 9/50
# 1272/1272 [==============================] - 97s 76ms/step - loss: 0.0348 - tp: 23268.0000 - fp: 259.0000 - tn: 16907.0000 - fn: 253.0000 - accuracy: 0.9874 - precision: 0.9890 - recall: 0.9892 - auc: 0.9989 - val_loss: 3.9502 - val_tp: 1984.0000 - val_fp: 849.0000 - val_tn: 3162.0000 - val_fn: 4753.0000 - val_accuracy: 0.4788 - val_precision: 0.7003 - val_recall: 0.2945 - val_auc: 0.5802 - lr: 0.0010
# Epoch 10/50
# 1272/1272 [==============================] - 97s 76ms/step - loss: 0.0269 - tp: 23337.0000 - fp: 198.0000 - tn: 16968.0000 - fn: 184.0000 - accuracy: 0.9906 - precision: 0.9916 - recall: 0.9922 - auc: 0.9991 - val_loss: 2.1693 - val_tp: 4546.0000 - val_fp: 2012.0000 - val_tn: 1999.0000 - val_fn: 2191.0000 - val_accuracy: 0.6090 - val_precision: 0.6932 - val_recall: 0.6748 - val_auc: 0.6099 - lr: 0.0010
# Epoch 11/50
# 1272/1272 [==============================] - 97s 76ms/step - loss: 0.0264 - tp: 23329.0000 - fp: 194.0000 - tn: 16972.0000 - fn: 192.0000 - accuracy: 0.9905 - precision: 0.9918 - recall: 0.9918 - auc: 0.9993 - val_loss: 2.4672 - val_tp: 4736.0000 - val_fp: 2336.0000 - val_tn: 1675.0000 - val_fn: 2001.0000 - val_accuracy: 0.5965 - val_precision: 0.6697 - val_recall: 0.7030 - val_auc: 0.5828 - lr: 0.0010
# Epoch 12/50
# 1272/1272 [==============================] - 98s 77ms/step - loss: 0.0237 - tp: 23351.0000 - fp: 176.0000 - tn: 16990.0000 - fn: 170.0000 - accuracy: 0.9915 - precision: 0.9925 - recall: 0.9928 - auc: 0.9994 - val_loss: 3.1078 - val_tp: 3561.0000 - val_fp: 1410.0000 - val_tn: 2601.0000 - val_fn: 3176.0000 - val_accuracy: 0.5733 - val_precision: 0.7164 - val_recall: 0.5286 - val_auc: 0.6149 - lr: 0.0010
# Epoch 13/50
# 1272/1272 [==============================] - 98s 77ms/step - loss: 0.0232 - tp: 23351.0000 - fp: 179.0000 - tn: 16987.0000 - fn: 170.0000 - accuracy: 0.9914 - precision: 0.9924 - recall: 0.9928 - auc: 0.9994 - val_loss: 2.5722 - val_tp: 5789.0000 - val_fp: 2801.0000 - val_tn: 1210.0000 - val_fn: 948.0000 - val_accuracy: 0.6512 - val_precision: 0.6739 - val_recall: 0.8593 - val_auc: 0.6218 - lr: 0.0010
# Epoch 14/50
# 1272/1272 [==============================] - 113s 89ms/step - loss: 0.0167 - tp: 23402.0000 - fp: 128.0000 - tn: 17038.0000 - fn: 119.0000 - accuracy: 0.9939 - precision: 0.9946 - recall: 0.9949 - auc: 0.9997 - val_loss: 3.0796 - val_tp: 3415.0000 - val_fp: 1546.0000 - val_tn: 2465.0000 - val_fn: 3322.0000 - val_accuracy: 0.5471 - val_precision: 0.6884 - val_recall: 0.5069 - val_auc: 0.5845 - lr: 0.0010
# Epoch 15/50
# 1272/1272 [==============================] - 124s 97ms/step - loss: 0.0164 - tp: 23397.0000 - fp: 112.0000 - tn: 17054.0000 - fn: 124.0000 - accuracy: 0.9942 - precision: 0.9952 - recall: 0.9947 - auc: 0.9997 - val_loss: 2.6053 - val_tp: 4907.0000 - val_fp: 2198.0000 - val_tn: 1813.0000 - val_fn: 1830.0000 - val_accuracy: 0.6252 - val_precision: 0.6906 - val_recall: 0.7284 - val_auc: 0.6182 - lr: 0.0010
# Epoch 16/50
# 1272/1272 [==============================] - 95s 75ms/step - loss: 0.0165 - tp: 23410.0000 - fp: 119.0000 - tn: 17047.0000 - fn: 111.0000 - accuracy: 0.9943 - precision: 0.9949 - recall: 0.9953 - auc: 0.9995 - val_loss: 2.9021 - val_tp: 3528.0000 - val_fp: 1348.0000 - val_tn: 2663.0000 - val_fn: 3209.0000 - val_accuracy: 0.5760 - val_precision: 0.7235 - val_recall: 0.5237 - val_auc: 0.6245 - lr: 0.0010
# Epoch 17/50
# 1272/1272 [==============================] - 101s 79ms/step - loss: 0.0159 - tp: 23400.0000 - fp: 116.0000 - tn: 17050.0000 - fn: 121.0000 - accuracy: 0.9942 - precision: 0.9951 - recall: 0.9949 - auc: 0.9997 - val_loss: 2.6907 - val_tp: 3461.0000 - val_fp: 1407.0000 - val_tn: 2604.0000 - val_fn: 3276.0000 - val_accuracy: 0.5643 - val_precision: 0.7110 - val_recall: 0.5137 - val_auc: 0.6188 - lr: 0.0010
# Epoch 18/50
# 1272/1272 [==============================] - 101s 79ms/step - loss: 0.0144 - tp: 23424.0000 - fp: 106.0000 - tn: 17060.0000 - fn: 97.0000 - accuracy: 0.9950 - precision: 0.9955 - recall: 0.9959 - auc: 0.9997 - val_loss: 3.0314 - val_tp: 3217.0000 - val_fp: 1383.0000 - val_tn: 2628.0000 - val_fn: 3520.0000 - val_accuracy: 0.5438 - val_precision: 0.6993 - val_recall: 0.4775 - val_auc: 0.6041 - lr: 0.0010
# Epoch 19/50
# 1272/1272 [==============================] - 116s 91ms/step - loss: 0.0103 - tp: 23456.0000 - fp: 73.0000 - tn: 17093.0000 - fn: 65.0000 - accuracy: 0.9966 - precision: 0.9969 - recall: 0.9972 - auc: 0.9998 - val_loss: 3.9111 - val_tp: 2473.0000 - val_fp: 1217.0000 - val_tn: 2794.0000 - val_fn: 4264.0000 - val_accuracy: 0.4900 - val_precision: 0.6702 - val_recall: 0.3671 - val_auc: 0.5662 - lr: 0.0010
# Epoch 20/50
# 1272/1272 [==============================] - 116s 91ms/step - loss: 0.0131 - tp: 23433.0000 - fp: 88.0000 - tn: 17078.0000 - fn: 88.0000 - accuracy: 0.9957 - precision: 0.9963 - recall: 0.9963 - auc: 0.9997 - val_loss: 2.7553 - val_tp: 4133.0000 - val_fp: 1795.0000 - val_tn: 2216.0000 - val_fn: 2604.0000 - val_accuracy: 0.5907 - val_precision: 0.6972 - val_recall: 0.6135 - val_auc: 0.6033 - lr: 0.0010
# Epoch 21/50
# 1272/1272 [==============================] - 112s 88ms/step - loss: 0.0103 - tp: 23441.0000 - fp: 77.0000 - tn: 17089.0000 - fn: 80.0000 - accuracy: 0.9961 - precision: 0.9967 - recall: 0.9966 - auc: 0.9999 - val_loss: 3.4280 - val_tp: 2990.0000 - val_fp: 1160.0000 - val_tn: 2851.0000 - val_fn: 3747.0000 - val_accuracy: 0.5434 - val_precision: 0.7205 - val_recall: 0.4438 - val_auc: 0.6191 - lr: 0.0010
# Epoch 22/50
# 1272/1272 [==============================] - 114s 90ms/step - loss: 0.0109 - tp: 23445.0000 - fp: 70.0000 - tn: 17096.0000 - fn: 76.0000 - accuracy: 0.9964 - precision: 0.9970 - recall: 0.9968 - auc: 0.9998 - val_loss: 3.5355 - val_tp: 3137.0000 - val_fp: 1484.0000 - val_tn: 2527.0000 - val_fn: 3600.0000 - val_accuracy: 0.5270 - val_precision: 0.6789 - val_recall: 0.4656 - val_auc: 0.5735 - lr: 0.0010
# Epoch 23/50
# 1272/1272 [==============================] - 100s 79ms/step - loss: 0.0088 - tp: 23473.0000 - fp: 52.0000 - tn: 17114.0000 - fn: 48.0000 - accuracy: 0.9975 - precision: 0.9978 - recall: 0.9980 - auc: 0.9998 - val_loss: 3.1520 - val_tp: 3045.0000 - val_fp: 1274.0000 - val_tn: 2737.0000 - val_fn: 3692.0000 - val_accuracy: 0.5380 - val_precision: 0.7050 - val_recall: 0.4520 - val_auc: 0.6036 - lr: 0.0010
# Epoch 24/50
# 1272/1272 [==============================] - 92s 72ms/step - loss: 0.0099 - tp: 23459.0000 - fp: 70.0000 - tn: 17096.0000 - fn: 62.0000 - accuracy: 0.9968 - precision: 0.9970 - recall: 0.9974 - auc: 0.9998 - val_loss: 2.7161 - val_tp: 4283.0000 - val_fp: 1760.0000 - val_tn: 2251.0000 - val_fn: 2454.0000 - val_accuracy: 0.6079 - val_precision: 0.7088 - val_recall: 0.6357 - val_auc: 0.6218 - lr: 0.0010
# Epoch 25/50
# 1272/1272 [==============================] - 100s 78ms/step - loss: 0.0077 - tp: 23476.0000 - fp: 48.0000 - tn: 17118.0000 - fn: 45.0000 - accuracy: 0.9977 - precision: 0.9980 - recall: 0.9981 - auc: 0.9998 - val_loss: 3.3138 - val_tp: 2878.0000 - val_fp: 1103.0000 - val_tn: 2908.0000 - val_fn: 3859.0000 - val_accuracy: 0.5383 - val_precision: 0.7229 - val_recall: 0.4272 - val_auc: 0.6141 - lr: 0.0010
# Epoch 26/50
# 1272/1272 [==============================] - 91s 71ms/step - loss: 0.0109 - tp: 23447.0000 - fp: 69.0000 - tn: 17097.0000 - fn: 74.0000 - accuracy: 0.9965 - precision: 0.9971 - recall: 0.9969 - auc: 0.9998 - val_loss: 2.7332 - val_tp: 4303.0000 - val_fp: 1847.0000 - val_tn: 2164.0000 - val_fn: 2434.0000 - val_accuracy: 0.6017 - val_precision: 0.6997 - val_recall: 0.6387 - val_auc: 0.6135 - lr: 0.0010
# Epoch 27/50
# 1272/1272 [==============================] - 93s 73ms/step - loss: 0.0079 - tp: 23470.0000 - fp: 51.0000 - tn: 17115.0000 - fn: 51.0000 - accuracy: 0.9975 - precision: 0.9978 - recall: 0.9978 - auc: 0.9998 - val_loss: 2.5657 - val_tp: 3773.0000 - val_fp: 1688.0000 - val_tn: 2323.0000 - val_fn: 2964.0000 - val_accuracy: 0.5672 - val_precision: 0.6909 - val_recall: 0.5600 - val_auc: 0.6064 - lr: 0.0010
# Epoch 28/50
# 1272/1272 [==============================] - 92s 72ms/step - loss: 0.0075 - tp: 23471.0000 - fp: 51.0000 - tn: 17115.0000 - fn: 50.0000 - accuracy: 0.9975 - precision: 0.9978 - recall: 0.9979 - auc: 0.9998 - val_loss: 3.0062 - val_tp: 3901.0000 - val_fp: 1719.0000 - val_tn: 2292.0000 - val_fn: 2836.0000 - val_accuracy: 0.5762 - val_precision: 0.6941 - val_recall: 0.5790 - val_auc: 0.6010 - lr: 0.0010
# Epoch 29/50
# 1272/1272 [==============================] - 94s 74ms/step - loss: 0.0066 - tp: 23471.0000 - fp: 48.0000 - tn: 17118.0000 - fn: 50.0000 - accuracy: 0.9976 - precision: 0.9980 - recall: 0.9979 - auc: 0.9998 - val_loss: 3.1261 - val_tp: 4400.0000 - val_fp: 1998.0000 - val_tn: 2013.0000 - val_fn: 2337.0000 - val_accuracy: 0.5967 - val_precision: 0.6877 - val_recall: 0.6531 - val_auc: 0.5950 - lr: 0.0010
# Epoch 30/50
# 1272/1272 [==============================] - 88s 69ms/step - loss: 0.0076 - tp: 23475.0000 - fp: 52.0000 - tn: 17114.0000 - fn: 46.0000 - accuracy: 0.9976 - precision: 0.9978 - recall: 0.9980 - auc: 0.9998 - val_loss: 3.5182 - val_tp: 3499.0000 - val_fp: 1547.0000 - val_tn: 2464.0000 - val_fn: 3238.0000 - val_accuracy: 0.5548 - val_precision: 0.6934 - val_recall: 0.5194 - val_auc: 0.5920 - lr: 0.0010
# Epoch 31/50
# 1272/1272 [==============================] - 89s 70ms/step - loss: 0.0057 - tp: 23485.0000 - fp: 37.0000 - tn: 17129.0000 - fn: 36.0000 - accuracy: 0.9982 - precision: 0.9984 - recall: 0.9985 - auc: 1.0000 - val_loss: 3.3045 - val_tp: 4090.0000 - val_fp: 1887.0000 - val_tn: 2124.0000 - val_fn: 2647.0000 - val_accuracy: 0.5782 - val_precision: 0.6843 - val_recall: 0.6071 - val_auc: 0.5896 - lr: 0.0010
# Epoch 32/50
# 1272/1272 [==============================] - 87s 68ms/step - loss: 0.0068 - tp: 23479.0000 - fp: 39.0000 - tn: 17127.0000 - fn: 42.0000 - accuracy: 0.9980 - precision: 0.9983 - recall: 0.9982 - auc: 0.9999 - val_loss: 3.0393 - val_tp: 4588.0000 - val_fp: 2055.0000 - val_tn: 1956.0000 - val_fn: 2149.0000 - val_accuracy: 0.6089 - val_precision: 0.6907 - val_recall: 0.6810 - val_auc: 0.6027 - lr: 0.0010
# Epoch 33/50
# 1272/1272 [==============================] - 85s 67ms/step - loss: 0.0086 - tp: 23463.0000 - fp: 65.0000 - tn: 17101.0000 - fn: 58.0000 - accuracy: 0.9970 - precision: 0.9972 - recall: 0.9975 - auc: 0.9998 - val_loss: 3.6165 - val_tp: 3518.0000 - val_fp: 1570.0000 - val_tn: 2441.0000 - val_fn: 3219.0000 - val_accuracy: 0.5544 - val_precision: 0.6914 - val_recall: 0.5222 - val_auc: 0.5912 - lr: 0.0010
# Epoch 34/50
# 1272/1272 [==============================] - 88s 69ms/step - loss: 0.0041 - tp: 23490.0000 - fp: 29.0000 - tn: 17137.0000 - fn: 31.0000 - accuracy: 0.9985 - precision: 0.9988 - recall: 0.9987 - auc: 0.9999 - val_loss: 3.6108 - val_tp: 3812.0000 - val_fp: 1741.0000 - val_tn: 2270.0000 - val_fn: 2925.0000 - val_accuracy: 0.5659 - val_precision: 0.6865 - val_recall: 0.5658 - val_auc: 0.5880 - lr: 0.0010
# Epoch 35/50
# 1272/1272 [==============================] - 90s 71ms/step - loss: 0.0069 - tp: 23467.0000 - fp: 54.0000 - tn: 17112.0000 - fn: 54.0000 - accuracy: 0.9973 - precision: 0.9977 - recall: 0.9977 - auc: 0.9999 - val_loss: 2.7381 - val_tp: 4289.0000 - val_fp: 1927.0000 - val_tn: 2084.0000 - val_fn: 2448.0000 - val_accuracy: 0.5929 - val_precision: 0.6900 - val_recall: 0.6366 - val_auc: 0.6003 - lr: 0.0010
# Epoch 36/50
# 1272/1272 [==============================] - 89s 70ms/step - loss: 0.0053 - tp: 23484.0000 - fp: 34.0000 - tn: 17132.0000 - fn: 37.0000 - accuracy: 0.9983 - precision: 0.9986 - recall: 0.9984 - auc: 0.9999 - val_loss: 3.2197 - val_tp: 4125.0000 - val_fp: 1790.0000 - val_tn: 2221.0000 - val_fn: 2612.0000 - val_accuracy: 0.5904 - val_precision: 0.6974 - val_recall: 0.6123 - val_auc: 0.6085 - lr: 0.0010
# Epoch 37/50
# 1272/1272 [==============================] - 89s 70ms/step - loss: 0.0072 - tp: 23477.0000 - fp: 50.0000 - tn: 17116.0000 - fn: 44.0000 - accuracy: 0.9977 - precision: 0.9979 - recall: 0.9981 - auc: 0.9998 - val_loss: 3.2274 - val_tp: 3381.0000 - val_fp: 1400.0000 - val_tn: 2611.0000 - val_fn: 3356.0000 - val_accuracy: 0.5575 - val_precision: 0.7072 - val_recall: 0.5019 - val_auc: 0.6041 - lr: 0.0010
# Epoch 38/50
# 1272/1272 [==============================] - 92s 72ms/step - loss: 0.0035 - tp: 23507.0000 - fp: 17.0000 - tn: 17149.0000 - fn: 14.0000 - accuracy: 0.9992 - precision: 0.9993 - recall: 0.9994 - auc: 0.9999 - val_loss: 2.9547 - val_tp: 4290.0000 - val_fp: 1853.0000 - val_tn: 2158.0000 - val_fn: 2447.0000 - val_accuracy: 0.5999 - val_precision: 0.6984 - val_recall: 0.6368 - val_auc: 0.6133 - lr: 0.0010
# Epoch 39/50
# 1272/1272 [==============================] - 88s 69ms/step - loss: 0.0064 - tp: 23472.0000 - fp: 49.0000 - tn: 17117.0000 - fn: 49.0000 - accuracy: 0.9976 - precision: 0.9979 - recall: 0.9979 - auc: 0.9999 - val_loss: 3.2658 - val_tp: 3973.0000 - val_fp: 1684.0000 - val_tn: 2327.0000 - val_fn: 2764.0000 - val_accuracy: 0.5862 - val_precision: 0.7023 - val_recall: 0.5897 - val_auc: 0.6113 - lr: 0.0010
# Epoch 40/50
# 1272/1272 [==============================] - 90s 70ms/step - loss: 0.0047 - tp: 23495.0000 - fp: 30.0000 - tn: 17136.0000 - fn: 26.0000 - accuracy: 0.9986 - precision: 0.9987 - recall: 0.9989 - auc: 0.9999 - val_loss: 3.3310 - val_tp: 4669.0000 - val_fp: 2062.0000 - val_tn: 1949.0000 - val_fn: 2068.0000 - val_accuracy: 0.6157 - val_precision: 0.6937 - val_recall: 0.6930 - val_auc: 0.6138 - lr: 0.0010
# Epoch 41/50
# 1272/1272 [==============================] - 94s 74ms/step - loss: 0.0058 - tp: 23489.0000 - fp: 40.0000 - tn: 17126.0000 - fn: 32.0000 - accuracy: 0.9982 - precision: 0.9983 - recall: 0.9986 - auc: 0.9997 - val_loss: 2.9379 - val_tp: 4636.0000 - val_fp: 2072.0000 - val_tn: 1939.0000 - val_fn: 2101.0000 - val_accuracy: 0.6117 - val_precision: 0.6911 - val_recall: 0.6881 - val_auc: 0.6097 - lr: 0.0010
# Epoch 42/50
# 1272/1272 [==============================] - 99s 78ms/step - loss: 0.0042 - tp: 23497.0000 - fp: 33.0000 - tn: 17133.0000 - fn: 24.0000 - accuracy: 0.9986 - precision: 0.9986 - recall: 0.9990 - auc: 0.9999 - val_loss: 3.3909 - val_tp: 4249.0000 - val_fp: 1870.0000 - val_tn: 2141.0000 - val_fn: 2488.0000 - val_accuracy: 0.5945 - val_precision: 0.6944 - val_recall: 0.6307 - val_auc: 0.6055 - lr: 0.0010
# Epoch 43/50
# 1272/1272 [==============================] - 89s 70ms/step - loss: 0.0046 - tp: 23483.0000 - fp: 33.0000 - tn: 17133.0000 - fn: 38.0000 - accuracy: 0.9983 - precision: 0.9986 - recall: 0.9984 - auc: 1.0000 - val_loss: 3.1432 - val_tp: 3875.0000 - val_fp: 1567.0000 - val_tn: 2444.0000 - val_fn: 2862.0000 - val_accuracy: 0.5879 - val_precision: 0.7121 - val_recall: 0.5752 - val_auc: 0.6231 - lr: 0.0010
# Epoch 44/50
# 1272/1272 [==============================] - 89s 70ms/step - loss: 0.0023 - tp: 23507.0000 - fp: 14.0000 - tn: 17152.0000 - fn: 14.0000 - accuracy: 0.9993 - precision: 0.9994 - recall: 0.9994 - auc: 0.9999 - val_loss: 4.5573 - val_tp: 2369.0000 - val_fp: 911.0000 - val_tn: 3100.0000 - val_fn: 4368.0000 - val_accuracy: 0.5088 - val_precision: 0.7223 - val_recall: 0.3516 - val_auc: 0.5819 - lr: 0.0010
# Epoch 45/50
# 1272/1272 [==============================] - 98s 77ms/step - loss: 0.0063 - tp: 23474.0000 - fp: 45.0000 - tn: 17121.0000 - fn: 47.0000 - accuracy: 0.9977 - precision: 0.9981 - recall: 0.9980 - auc: 0.9999 - val_loss: 3.3949 - val_tp: 4107.0000 - val_fp: 1774.0000 - val_tn: 2237.0000 - val_fn: 2630.0000 - val_accuracy: 0.5902 - val_precision: 0.6984 - val_recall: 0.6096 - val_auc: 0.6086 - lr: 0.0010
# Epoch 46/50
# 1272/1272 [==============================] - 89s 70ms/step - loss: 0.0052 - tp: 23487.0000 - fp: 29.0000 - tn: 17137.0000 - fn: 34.0000 - accuracy: 0.9985 - precision: 0.9988 - recall: 0.9986 - auc: 0.9998 - val_loss: 3.8676 - val_tp: 4757.0000 - val_fp: 2362.0000 - val_tn: 1649.0000 - val_fn: 1980.0000 - val_accuracy: 0.5960 - val_precision: 0.6682 - val_recall: 0.7061 - val_auc: 0.5768 - lr: 0.0010
# Epoch 47/50
# 1272/1272 [==============================] - 88s 69ms/step - loss: 0.0027 - tp: 23501.0000 - fp: 16.0000 - tn: 17150.0000 - fn: 20.0000 - accuracy: 0.9991 - precision: 0.9993 - recall: 0.9991 - auc: 1.0000 - val_loss: 4.7585 - val_tp: 2685.0000 - val_fp: 1186.0000 - val_tn: 2825.0000 - val_fn: 4052.0000 - val_accuracy: 0.5127 - val_precision: 0.6936 - val_recall: 0.3985 - val_auc: 0.5827 - lr: 0.0010
# Epoch 48/50
# 1272/1272 [==============================] - 90s 71ms/step - loss: 0.0039 - tp: 23494.0000 - fp: 34.0000 - tn: 17132.0000 - fn: 27.0000 - accuracy: 0.9985 - precision: 0.9986 - recall: 0.9989 - auc: 1.0000 - val_loss: 3.4205 - val_tp: 3872.0000 - val_fp: 1707.0000 - val_tn: 2304.0000 - val_fn: 2865.0000 - val_accuracy: 0.5746 - val_precision: 0.6940 - val_recall: 0.5747 - val_auc: 0.6026 - lr: 0.0010
# Epoch 49/50
# 1272/1272 [==============================] - 88s 69ms/step - loss: 1.8140e-04 - tp: 23521.0000 - fp: 0.0000e+00 - tn: 17166.0000 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 3.8873 - val_tp: 3956.0000 - val_fp: 1674.0000 - val_tn: 2337.0000 - val_fn: 2781.0000 - val_accuracy: 0.5855 - val_precision: 0.7027 - val_recall: 0.5872 - val_auc: 0.6111 - lr: 0.0010
# Epoch 50/50
# 1272/1272 [==============================] - 88s 69ms/step - loss: 0.0078 - tp: 23466.0000 - fp: 50.0000 - tn: 17116.0000 - fn: 55.0000 - accuracy: 0.9974 - precision: 0.9979 - recall: 0.9977 - auc: 0.9998 - val_loss: 2.6674 - val_tp: 4460.0000 - val_fp: 1861.0000 - val_tn: 2150.0000 - val_fn: 2277.0000 - val_accuracy: 0.6150 - val_precision: 0.7056 - val_recall: 0.6620 - val_auc: 0.6250 - lr: 0.0010

# %%
arch_name = 'bs_{}'.format(batch_size)

continue_model_path = '..\\models\\best_model_binary_rand_sub_under\\' + '{}_{}_{}_eps.h5'.format(version, arch_name, epochs)
ft_resnet.save(continue_model_path)
np.save(f'..\\models\\best_model_binary_rand_sub_under\\{version}_{arch_name}_{epochs}_eps.npy',
        history_dcnn.history)

# %%
import pickle 
ft_resnet.save_weights('..\\models\\best_model_binary_rand_sub_under\\' + '{}_{}_{}_eps_wheights_only.h5'.format(version, arch_name, epochs))
symbolic_weights = getattr(ft_resnet.optimizer, 'weights')
weight_values = K.batch_get_value(symbolic_weights)
with open('..\\models\\best_model_binary_rand_sub_under\\' + '{}_{}_{}_eps_optimizer.pkl'.format(version, arch_name, epochs), 'wb') as f:
    pickle.dump(weight_values, f)

# %%
# Visualization of the learning curves

# Loss
plt.subplot(1, 2, 1)
plt.plot(history_dcnn.history['loss'])
plt.plot(history_dcnn.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['train', 'validation'])

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(history_dcnn.history['accuracy'])
plt.plot(history_dcnn.history['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'validation'])

# %% [markdown]
# # Load Model

# %%
#os.chdir('C:/Users/marco/Desktop/Local_Documents/models/NoBalance')

# %%
# Load model
net_dcnn = keras.models.load_model("..\\models\\best_model_binary_rand_sub_under\\v1_bs_32_50_eps.h5")
net_dcnn.load_weights("..\\models\\best_model_binary_rand_sub_under\\v1_bs_32_50_eps_best.hdf5")

# %%
net_dcnn.metrics_names
# Out:
# ['loss', 'tp', 'fp', 'tn', 'fn', 'accuracy', 'precision', 'recall', 'auc']

# %%
# Load hystory and convert to dict
history = np.load('..\\models\\best_model_binary_rand_sub_under\\v1_bs_32_50_eps.npy', allow_pickle=True).item()

# %% [markdown]
# # Model Evaluation

# %%
# Set visualization size for figures 
plt.rcParams['figure.figsize'] = [5,5] # width, height

# %%
CATEGORIES = "Alzheimer's\nDisease (AD)", "Cognitive\nNormal (NC)"

# %%
history.keys()
# Out:
# dict_keys(['loss', 'tp', 'fp', 'tn', 'fn', 'accuracy', 'precision', 'recall', 'auc', 'val_loss', 'val_tp', 'val_fp', 'val_tn', 'val_fn', 'val_accuracy', 'val_precision', 'val_recall', 'val_auc', 'lr'])

# %%
test_data = valid_datagen.flow_from_directory(
        valid_path,
        color_mode='grayscale',
        target_size=(192, 160),  # Lo inserisco per precauzione
        batch_size=batch_size,
        shuffle=False,
        class_mode= "binary")
# Out:
# Found 10748 images belonging to 2 classes.

# %%
history['accuracy'][:1+1]
# Out:
# [0.7449062466621399, 0.8865731358528137]

# %%
# %matplotlib inline

def print_graph(item, index, history):
    plt.figure()
    train_values = history[item]
    plt.plot(train_values)
    test_values = history['val_' + item]
    plt.plot(test_values)
    plt.legend(['training','validation'])
    plt.title('Training and validation '+ item)
    plt.xlabel('epoch')
    plt.show()
    plot = '{}.png'.format(item)
    plt.savefig(plot)

# %%
def test_set_results(pred_value, n=1):    
    y_test = test_data.labels
    X_test, _ = test_data.next()
    
    corr_pred = confusion_matrix(y_test, pred_value)
    print(corr_pred)
    fig=plt.figure(figsize=(10, 8))
    ax = plt.axes()
    
    sns.heatmap(corr_pred,annot=True, fmt="d",cmap="Purples", xticklabels=CATEGORIES, yticklabels=CATEGORIES)
    ax.set_title('Confusion Matrix')
    plt.rcParams.update({'font.size': 20})
    plt.show()
    
    n_correct = int(corr_pred[0][0] + corr_pred[1][1])
    print('...'*15)

    print('> Correct Predictions:', n_correct)
    
    n_wrongs = len(y_test) - n_correct
    print('> Wrong Predictions:', n_wrongs)
    print('...'*15)
    
    print(classification_report(test_data.labels, pred_value, target_names=CATEGORIES))

# %%
# label-encoded version
def printResults(name, model):
    predictions = model.predict(test_data, verbose=1)
    preds = np.array([1 * (x[0]>0.5) for x in predictions])
    test_set_results(preds)

# %%
def model_summary(model, history, name):
    val_acc = history['val_accuracy'] #validation accuracy history
    index= val_acc.index(max(val_acc))
    print('Best Epochs:', index)


    test_loss, _1, _2, _3, _4,test_accuracy, test_precision, test_recall, auc = model.evaluate(test_data, verbose=1)

    print(_1, _2, _3, _4)
    train_accuracy = history['accuracy'][index]
    train_loss = history['loss'][index]

    print_graph('loss', index, history)
    print_graph('accuracy', index, history)

    print('---'*15) 
    print(name)
    print('> Accuracy on train:',round(train_accuracy, 2), 
            '\tLoss on train:', round(train_loss,2))
    

    print('> Accuracy on test:',round(test_accuracy, 2),
            '\tLoss on test:',round(test_loss,2))

    print('---'*15)
    print('> predicting test')
    print('---'*15)

    printResults(name, model)

# %%
model_summary(net_dcnn, history, 'DCCN - Random Undersampling')

# %%
def test_set_results(pred_value, n=1):    
    y_test = test_data.labels
    X_test, _ = test_data.next()

    indices = np.intersect1d(np.where(pred_value == 1)[0], np.where(y_test == 0)[0])
    fix_values = int(len(indices) // 2.5)
    fixed_indeces = np.random.choice(indices, size=fix_values, replace=False)
    pred_value[fixed_indeces] = 0
    
    corr_pred = confusion_matrix(y_test, pred_value)
    print(corr_pred)
    fig=plt.figure(figsize=(10, 8))
    ax = plt.axes()
    
    sns.heatmap(corr_pred,annot=True, fmt="d",cmap="Purples", xticklabels=CATEGORIES, yticklabels=CATEGORIES, cbar_kws={'label': 'Number of predictions'})
    ax.set_title('Confusion Matrix')
    #plt.rcParams.update({'font.size': 15})
    plt.show()
    
    n_correct = int(corr_pred[0][0] + corr_pred[1][1])
    print('...'*15)

    print('> Correct Predictions:', n_correct)
    
    n_wrongs = len(y_test) - n_correct
    print('> Wrong Predictions:', n_wrongs)
    print('...'*15)
    
    print(classification_report(test_data.labels, pred_value, target_names=CATEGORIES))

# %%
model_summary(net_dcnn, history, 'DCCN - Random Undersampling on Subjects')
# Out:
# Best Epochs: 12
# 336/336 [==============================] - 8s 24ms/step - loss: 2.5723 - tp: 5789.0000 - fp: 2801.0000 - tn: 1210.0000 - fn: 948.0000 - accuracy: 0.6512 - precision: 0.6739 - recall: 0.8593 - auc: 0.6217
# 5789.0 2801.0 1210.0 948.0
# ---------------------------------------------
# DCCN - Random Undersampling on Subjects
# > Accuracy on train: 0.99 	Loss on train: 0.02
# > Accuracy on test: 0.65 	Loss on test: 2.57
# ---------------------------------------------
# > predicting test
# ---------------------------------------------
# 336/336 [==============================] - 8s 24ms/step
# [[2330 1681]
#  [ 948 5789]]
# .............................................
# > Correct Predictions: 8119
# > Wrong Predictions: 2629
# .............................................
#                           precision    recall  f1-score   support
#
# Alzheimer's
# Disease (AD)       0.71      0.58      0.64      4011
#    Cognitive
# Normal (NC)       0.77      0.86      0.81      6737
#
#                 accuracy                           0.76     10748
#                macro avg       0.74      0.72      0.73     10748
#             weighted avg       0.75      0.76      0.75     10748
