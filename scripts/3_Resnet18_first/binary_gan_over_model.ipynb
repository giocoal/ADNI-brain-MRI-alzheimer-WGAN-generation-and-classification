# %% [markdown]
# **Importing libraries**

# %%
# Keras e TF

#import tensorflow
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, Conv1D, MaxPooling2D, Dense, Flatten, BatchNormalization, Activation, AveragePooling2D, Input, Flatten, Dropout
from keras.callbacks import ModelCheckpoint

# Sk-Learn
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix, ConfusionMatrixDisplay, roc_curve, roc_auc_score, RocCurveDisplay, accuracy_score, classification_report, confusion_matrix

# Base
import os 
from pathlib import Path
from matplotlib import pyplot as plt
import seaborn as sns # 
import numpy as np #
import pandas as pd # 

from keras.utils import load_img

import pydot
import pydotplus
from pydotplus import graphviz

from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import backend as K
from custom_resnet import ResNet18


from keras.models import Model
from keras.optimizers import Adam

# %%
keras.__version__
# Out:
# '2.10.0'

# %% [markdown]
# **Setting path to the dataset**

# %%
os.chdir(Path(str(Path(os.getcwd()).parent.absolute().parent.absolute()) +
              '\\adni-images-Full-resized160x192-binary'))

# %%
print(os.getcwd())
# Out:
# d:\Projects\ADNI-brain-MRI-alzheimer-classification-and-GAN-generation\adni-images-Full-resized160x192-binary

# %% [markdown]
# # Loading Dataset

# %%
data_dir = Path(os.getcwd())

def data_mean_std():
    names = []
    for root, dirs, files in os.walk(data_dir):
        if "train" in root:
            for file in files:
                names.append(root + '/' + file)
    
    print(len(names))
                
    array = []
    for name in names:
        try:
            img = load_img(name, color_mode = 'grayscale', target_size = (160, 192))
            img_array = np.asarray(img)
            array.append(img_array)
        except:
            print("Name: ", name)
            continue
    
    print(img_array.shape) # Correct amount of images

    array = np.asarray(array)
    print(array.shape)
    print(array.mean().shape, array.std().shape)
    return array.mean(), array.std()
""" 
stats_file = open(stats_path, 'r')
stats_lst = stats_file.read().split('\n')
mean = float(stats_lst[0])
std = float(stats_lst[1])"""
mean, std = data_mean_std()

print(mean, std)
# Out:
# 61829
# Name:  d:\Projects\ADNI-brain-MRI-alzheimer-classification-and-GAN-generation\adni-images-Full-resized160x192-binary\no_balance_binary\logs_no_balance_binary\train/events.out.tfevents.1686073730.GIORGIO-LAPTOP.43900.0.v2
# Name:  d:\Projects\ADNI-brain-MRI-alzheimer-classification-and-GAN-generation\adni-images-Full-resized160x192-binary\train\ad/ADNI_021_S_0753_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20071115091031185_S18712_I82162_101.png

# %% [markdown]
# Use the pre-computed values (oversampling GAN):

# %%
mean = 35.80925715423529
std = 45.16736479384096

# %%
def normalize(x):
    return (x - mean) / std

# %%
batch_size = 32 # Batch size

train_path = './train_gan_over'
test_path = './test'
valid_path = './valid'
#rescale = 1./255.
train_datagen = ImageDataGenerator(preprocessing_function = normalize)
test_datagen = ImageDataGenerator(preprocessing_function = normalize)
valid_datagen = ImageDataGenerator(preprocessing_function = normalize)

# %%
train_data = train_datagen.flow_from_directory(
        train_path,
        color_mode = 'grayscale',
        target_size=(192, 160),  # Lo inserisco per precauzione
        batch_size=batch_size,
        seed=123,
        shuffle=True,
        class_mode= "binary")
# Out:
# Found 79378 images belonging to 2 classes.

# %%
validation_data = valid_datagen.flow_from_directory(
        valid_path,
        classes={'ad': 0, 
                'nor': 1},
        color_mode='grayscale',
        target_size=(192, 160),  # Lo inserisco per precauzione
        batch_size=batch_size,
        seed=123,
        shuffle=True,
        class_mode= "binary")
# Out:
# Found 10748 images belonging to 2 classes.

# %%
# Test set
test_data = test_datagen.flow_from_directory(
        test_path,
        color_mode='grayscale',
        target_size=(192, 160),  # Lo inserisco per precauzione
        batch_size=batch_size,
        shuffle=False,
        class_mode= "binary")
# Out:
# Found 4572 images belonging to 2 classes.

# %%
train_data.class_indices
# Out:
# {'ad': 0, 'nor': 1}

# %%
validation_data.class_indices
# Out:
# {'ad': 0, 'nor': 1}

# %%
test_data.class_indices
# Out:
# {'ad': 0, 'nor': 1}

# %%
train_ad = len(os.listdir(os.getcwd() + '\\train_gan_over\\ad'))
train_nor = len(os.listdir(os.getcwd() + '\\train_gan_over\\nor'))
train_tot = train_ad + train_nor
print(train_ad/train_tot, train_nor/train_tot)
# Out:
# 0.5 0.5

# %%
test_ad = len(os.listdir(os.getcwd() + '\\test\\ad'))
test_nor = len(os.listdir(os.getcwd() + '\\test\\nor'))
test_tot = test_ad + test_nor
print(test_ad/test_tot, test_nor/test_tot)
# Out:
# 0.5201224846894138 0.4798775153105862

# %%
valid_ad = len(os.listdir(os.getcwd() + '\\valid\\ad'))
valid_nor = len(os.listdir(os.getcwd() + '\\valid\\nor'))
valid_tot = valid_ad + valid_nor
print(valid_ad/valid_tot, valid_nor/valid_tot)
# Out:
# 0.3731857089691105 0.6268142910308895

# %% [markdown]
# # Model Definition

# %% [markdown]
# Changing the folder to data path to save weights into

# %%
os.chdir(Path(str(Path(os.getcwd()).parent.absolute()) + '\\scripts\\3_Resnet18_first'))

# %%
os.getcwd()
# Out:
# 'd:\\Projects\\ADNI-brain-MRI-alzheimer-classification-and-GAN-generation\\scripts\\3_Resnet18_first'

# %%
METRICS = [ 
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'),
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc')
]

# %%
early_stopper = keras.callbacks.EarlyStopping(monitor='val_loss', patience=100)

# %%
version = "v1"
epochs = 50
arch_name = 'bs_{}'.format(batch_size)

tb = TensorBoard(log_dir =os.getcwd() + '\\binary_gan_over\\logs_binary_gan_over', write_graph = True)

lr_reducer = ReduceLROnPlateau(monitor='loss', factor=np.sqrt(0.1), patience=10, cooldown=0, min_lr=1e-5)

model_chkp = ModelCheckpoint(filepath='D:\\Projects\\ADNI-brain-MRI-alzheimer-classification-and-GAN-generation\\models\\best_model_binary_gan_over\\{}_{}_{}_eps_best.hdf5'.format(version, arch_name, epochs),
                            # monitor='val_quadratic_kappa_score',
                            monitor='val_accuracy',
                            save_best_only=True, save_weights_only=True, mode='max')

#resnet = ResNet18()
#resnet = ResNet18(classes=3, input_shape=(160, 192))
resnet = ResNet18(classes=2)


#model = keras.applications.resnet50.ResNet50(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000)
#model.summary()

#resnet.layers.pop()
#for layer in resnet.layers:
#    layer.trainable = False

x = resnet.layers[-1].output

# x = Dropout(0.25)(x)

x = Dense(1, activation = 'sigmoid')(x)


ft_resnet = Model(resnet.input, x)
optimizer = Adam(learning_rate = 0.001)
ft_resnet.compile(optimizer = optimizer, loss = 'BinaryCrossentropy', metrics = METRICS)

print("model loaded")

ft_resnet.summary()
# Out:
# <class 'keras.engine.keras_tensor.KerasTensor'>
# model loaded
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 192, 160, 1  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 198, 166, 1)  0           ['input_2[0][0]']
#
#  conv1 (Conv2D)                 (None, 96, 80, 64)   3200        ['conv1_pad[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 96, 80, 64)   256         ['conv1[0][0]']
#
#  leaky_re_lu_17 (LeakyReLU)     (None, 96, 80, 64)   0           ['bn_conv1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 47, 39, 64)  0           ['leaky_re_lu_17[0][0]']
#
#  res2a_branch2a (Conv2D)        (None, 47, 39, 64)   36928       ['max_pooling2d_1[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 47, 39, 64)  256         ['res2a_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_18 (LeakyReLU)     (None, 47, 39, 64)   0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv2D)        (None, 47, 39, 64)   36928       ['leaky_re_lu_18[0][0]']
#
#  res2a_branch1 (Conv2D)         (None, 47, 39, 64)   4160        ['max_pooling2d_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 47, 39, 64)  256         ['res2a_branch2b[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 47, 39, 64)  256         ['res2a_branch1[0][0]']
#  on)
#
#  add_8 (Add)                    (None, 47, 39, 64)   0           ['bn2a_branch2b[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  leaky_re_lu_19 (LeakyReLU)     (None, 47, 39, 64)   0           ['add_8[0][0]']
#
#  res2b_branch2a (Conv2D)        (None, 47, 39, 64)   36928       ['leaky_re_lu_19[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 47, 39, 64)  256         ['res2b_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_20 (LeakyReLU)     (None, 47, 39, 64)   0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv2D)        (None, 47, 39, 64)   36928       ['leaky_re_lu_20[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 47, 39, 64)  256         ['res2b_branch2b[0][0]']
#  ion)
#
#  add_9 (Add)                    (None, 47, 39, 64)   0           ['bn2b_branch2b[0][0]',
#                                                                   'leaky_re_lu_19[0][0]']
#
#  leaky_re_lu_21 (LeakyReLU)     (None, 47, 39, 64)   0           ['add_9[0][0]']
#
#  res3a_branch2a (Conv2D)        (None, 24, 20, 128)  73856       ['leaky_re_lu_21[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 24, 20, 128)  512        ['res3a_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_22 (LeakyReLU)     (None, 24, 20, 128)  0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv2D)        (None, 24, 20, 128)  147584      ['leaky_re_lu_22[0][0]']
#
#  res3a_branch1 (Conv2D)         (None, 24, 20, 128)  8320        ['leaky_re_lu_21[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 24, 20, 128)  512        ['res3a_branch2b[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 24, 20, 128)  512        ['res3a_branch1[0][0]']
#  on)
#
#  add_10 (Add)                   (None, 24, 20, 128)  0           ['bn3a_branch2b[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  leaky_re_lu_23 (LeakyReLU)     (None, 24, 20, 128)  0           ['add_10[0][0]']
#
#  res3b_branch2a (Conv2D)        (None, 24, 20, 128)  147584      ['leaky_re_lu_23[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 24, 20, 128)  512        ['res3b_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_24 (LeakyReLU)     (None, 24, 20, 128)  0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv2D)        (None, 24, 20, 128)  147584      ['leaky_re_lu_24[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 24, 20, 128)  512        ['res3b_branch2b[0][0]']
#  ion)
#
#  add_11 (Add)                   (None, 24, 20, 128)  0           ['bn3b_branch2b[0][0]',
#                                                                   'leaky_re_lu_23[0][0]']
#
#  leaky_re_lu_25 (LeakyReLU)     (None, 24, 20, 128)  0           ['add_11[0][0]']
#
#  res4a_branch2a (Conv2D)        (None, 12, 10, 256)  295168      ['leaky_re_lu_25[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 12, 10, 256)  1024       ['res4a_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_26 (LeakyReLU)     (None, 12, 10, 256)  0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv2D)        (None, 12, 10, 256)  590080      ['leaky_re_lu_26[0][0]']
#
#  res4a_branch1 (Conv2D)         (None, 12, 10, 256)  33024       ['leaky_re_lu_25[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 12, 10, 256)  1024       ['res4a_branch2b[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 12, 10, 256)  1024       ['res4a_branch1[0][0]']
#  on)
#
#  add_12 (Add)                   (None, 12, 10, 256)  0           ['bn4a_branch2b[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  leaky_re_lu_27 (LeakyReLU)     (None, 12, 10, 256)  0           ['add_12[0][0]']
#
#  res4b_branch2a (Conv2D)        (None, 12, 10, 256)  590080      ['leaky_re_lu_27[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 12, 10, 256)  1024       ['res4b_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_28 (LeakyReLU)     (None, 12, 10, 256)  0           ['bn4b_branch2a[0][0]']
#
#  res4b_branch2b (Conv2D)        (None, 12, 10, 256)  590080      ['leaky_re_lu_28[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 12, 10, 256)  1024       ['res4b_branch2b[0][0]']
#  ion)
#
#  add_13 (Add)                   (None, 12, 10, 256)  0           ['bn4b_branch2b[0][0]',
#                                                                   'leaky_re_lu_27[0][0]']
#
#  leaky_re_lu_29 (LeakyReLU)     (None, 12, 10, 256)  0           ['add_13[0][0]']
#
#  res5a_branch2a (Conv2D)        (None, 6, 5, 512)    1180160     ['leaky_re_lu_29[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 6, 5, 512)   2048        ['res5a_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_30 (LeakyReLU)     (None, 6, 5, 512)    0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv2D)        (None, 6, 5, 512)    2359808     ['leaky_re_lu_30[0][0]']
#
#  res5a_branch1 (Conv2D)         (None, 6, 5, 512)    131584      ['leaky_re_lu_29[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 6, 5, 512)   2048        ['res5a_branch2b[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 6, 5, 512)   2048        ['res5a_branch1[0][0]']
#  on)
#
#  add_14 (Add)                   (None, 6, 5, 512)    0           ['bn5a_branch2b[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  leaky_re_lu_31 (LeakyReLU)     (None, 6, 5, 512)    0           ['add_14[0][0]']
#
#  res5b_branch2a (Conv2D)        (None, 6, 5, 512)    2359808     ['leaky_re_lu_31[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 6, 5, 512)   2048        ['res5b_branch2a[0][0]']
#  ion)
#
#  leaky_re_lu_32 (LeakyReLU)     (None, 6, 5, 512)    0           ['bn5b_branch2a[0][0]']
#
#  res5b_branch2b (Conv2D)        (None, 6, 5, 512)    2359808     ['leaky_re_lu_32[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 6, 5, 512)   2048        ['res5b_branch2b[0][0]']
#  ion)
#
#  add_15 (Add)                   (None, 6, 5, 512)    0           ['bn5b_branch2b[0][0]',
#                                                                   'leaky_re_lu_31[0][0]']
#
#  leaky_re_lu_33 (LeakyReLU)     (None, 6, 5, 512)    0           ['add_15[0][0]']
#
#  avg_pool (AveragePooling2D)    (None, 1, 1, 512)    0           ['leaky_re_lu_33[0][0]']
#
#  flatten_1 (Flatten)            (None, 512)          0           ['avg_pool[0][0]']
#
#  dense_1 (Dense)                (None, 1)            513         ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 11,189,569
# Trainable params: 11,179,841
# Non-trainable params: 9,728
# __________________________________________________________________________________________________

# %% [markdown]
# Changing back the folder to data path

# %%
os.chdir(Path(str(Path(os.getcwd()).parent.absolute().parent.absolute()) + '\\adni-images-Full-resized160x192-binary'))
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 os.chdir(Path(str(Path(os.getcwd()).parent.absolute().parent.absolute()) + '\\adni-images-Full-resized160x192-binary'))
#       2 os.getcwd()
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'd:\\Projects\\adni-images-Full-resized160x192-binary'

# %%
print(train_tot, valid_tot)

train_steps = np.ceil(train_tot/batch_size)
valid_steps = np.ceil(valid_tot/batch_size)

print (train_steps, valid_steps)

#fit_generator

history_dcnn = ft_resnet.fit(train_data, 
                             steps_per_epoch=train_steps,
                             epochs=epochs,
                             workers = 4,
                             callbacks = [tb, model_chkp, lr_reducer, early_stopper],
                             validation_data = validation_data, 
                             validation_steps = valid_steps)
# Out:
# 79378 10748
# 2481.0 336.0
# Epoch 1/50
# 2481/2481 [==============================] - 150s 59ms/step - loss: 0.3839 - tp: 34768.0000 - fp: 8726.0000 - tn: 34185.0000 - fn: 8131.0000 - accuracy: 0.8036 - precision: 0.7994 - recall: 0.8105 - auc: 0.8945 - val_loss: 1.5661 - val_tp: 2652.0000 - val_fp: 883.0000 - val_tn: 3128.0000 - val_fn: 4085.0000 - val_accuracy: 0.5378 - val_precision: 0.7502 - val_recall: 0.3936 - val_auc: 0.6322 - lr: 0.0010
# Epoch 2/50
# 2481/2481 [==============================] - 143s 58ms/step - loss: 0.1933 - tp: 36849.0000 - fp: 3455.0000 - tn: 36234.0000 - fn: 2840.0000 - accuracy: 0.9207 - precision: 0.9143 - recall: 0.9284 - auc: 0.9767 - val_loss: 1.1138 - val_tp: 5367.0000 - val_fp: 2407.0000 - val_tn: 1604.0000 - val_fn: 1370.0000 - val_accuracy: 0.6486 - val_precision: 0.6904 - val_recall: 0.7966 - val_auc: 0.6659 - lr: 0.0010
# Epoch 3/50
# 2481/2481 [==============================] - 143s 57ms/step - loss: 0.1171 - tp: 37943.0000 - fp: 2010.0000 - tn: 37679.0000 - fn: 1746.0000 - accuracy: 0.9527 - precision: 0.9497 - recall: 0.9560 - auc: 0.9913 - val_loss: 1.5855 - val_tp: 6313.0000 - val_fp: 2925.0000 - val_tn: 1086.0000 - val_fn: 424.0000 - val_accuracy: 0.6884 - val_precision: 0.6834 - val_recall: 0.9371 - val_auc: 0.7199 - lr: 0.0010
# Epoch 4/50
# 2481/2481 [==============================] - 142s 57ms/step - loss: 0.0788 - tp: 38503.0000 - fp: 1271.0000 - tn: 38418.0000 - fn: 1186.0000 - accuracy: 0.9690 - precision: 0.9680 - recall: 0.9701 - auc: 0.9959 - val_loss: 1.3492 - val_tp: 6034.0000 - val_fp: 2434.0000 - val_tn: 1577.0000 - val_fn: 703.0000 - val_accuracy: 0.7081 - val_precision: 0.7126 - val_recall: 0.8957 - val_auc: 0.7186 - lr: 0.0010
# Epoch 5/50
# 2481/2481 [==============================] - 142s 57ms/step - loss: 0.0565 - tp: 38866.0000 - fp: 879.0000 - tn: 38810.0000 - fn: 823.0000 - accuracy: 0.9786 - precision: 0.9779 - recall: 0.9793 - auc: 0.9977 - val_loss: 1.6461 - val_tp: 3205.0000 - val_fp: 933.0000 - val_tn: 3078.0000 - val_fn: 3532.0000 - val_accuracy: 0.5846 - val_precision: 0.7745 - val_recall: 0.4757 - val_auc: 0.6977 - lr: 0.0010
# Epoch 6/50
# 2481/2481 [==============================] - 143s 58ms/step - loss: 0.0439 - tp: 39067.0000 - fp: 651.0000 - tn: 39038.0000 - fn: 622.0000 - accuracy: 0.9840 - precision: 0.9836 - recall: 0.9843 - auc: 0.9985 - val_loss: 2.0443 - val_tp: 2415.0000 - val_fp: 683.0000 - val_tn: 3328.0000 - val_fn: 4322.0000 - val_accuracy: 0.5343 - val_precision: 0.7795 - val_recall: 0.3585 - val_auc: 0.6669 - lr: 0.0010
# Epoch 7/50
# 2481/2481 [==============================] - 143s 58ms/step - loss: 0.0339 - tp: 39207.0000 - fp: 494.0000 - tn: 39195.0000 - fn: 482.0000 - accuracy: 0.9877 - precision: 0.9876 - recall: 0.9879 - auc: 0.9989 - val_loss: 2.3641 - val_tp: 3052.0000 - val_fp: 934.0000 - val_tn: 3077.0000 - val_fn: 3685.0000 - val_accuracy: 0.5702 - val_precision: 0.7657 - val_recall: 0.4530 - val_auc: 0.6680 - lr: 0.0010
# Epoch 8/50
# 2481/2481 [==============================] - 143s 58ms/step - loss: 0.0283 - tp: 39264.0000 - fp: 406.0000 - tn: 39283.0000 - fn: 425.0000 - accuracy: 0.9895 - precision: 0.9898 - recall: 0.9893 - auc: 0.9993 - val_loss: 2.4778 - val_tp: 2968.0000 - val_fp: 965.0000 - val_tn: 3046.0000 - val_fn: 3769.0000 - val_accuracy: 0.5595 - val_precision: 0.7546 - val_recall: 0.4406 - val_auc: 0.6432 - lr: 0.0010
# Epoch 9/50
# 2481/2481 [==============================] - 142s 57ms/step - loss: 0.0238 - tp: 39355.0000 - fp: 356.0000 - tn: 39333.0000 - fn: 334.0000 - accuracy: 0.9913 - precision: 0.9910 - recall: 0.9916 - auc: 0.9994 - val_loss: 1.8538 - val_tp: 4513.0000 - val_fp: 1202.0000 - val_tn: 2809.0000 - val_fn: 2224.0000 - val_accuracy: 0.6812 - val_precision: 0.7897 - val_recall: 0.6699 - val_auc: 0.7364 - lr: 0.0010
# Epoch 10/50
# 2481/2481 [==============================] - 142s 57ms/step - loss: 0.0208 - tp: 39415.0000 - fp: 297.0000 - tn: 39392.0000 - fn: 274.0000 - accuracy: 0.9928 - precision: 0.9925 - recall: 0.9931 - auc: 0.9995 - val_loss: 2.7320 - val_tp: 6406.0000 - val_fp: 3053.0000 - val_tn: 958.0000 - val_fn: 331.0000 - val_accuracy: 0.6852 - val_precision: 0.6772 - val_recall: 0.9509 - val_auc: 0.6780 - lr: 0.0010
# Epoch 11/50
# 2481/2481 [==============================] - 149s 60ms/step - loss: 0.0181 - tp: 39429.0000 - fp: 276.0000 - tn: 39413.0000 - fn: 260.0000 - accuracy: 0.9932 - precision: 0.9930 - recall: 0.9934 - auc: 0.9997 - val_loss: 3.0777 - val_tp: 6555.0000 - val_fp: 3212.0000 - val_tn: 799.0000 - val_fn: 182.0000 - val_accuracy: 0.6842 - val_precision: 0.6711 - val_recall: 0.9730 - val_auc: 0.6589 - lr: 0.0010
# Epoch 12/50
# 2481/2481 [==============================] - 152s 61ms/step - loss: 0.0165 - tp: 39464.0000 - fp: 231.0000 - tn: 39458.0000 - fn: 225.0000 - accuracy: 0.9943 - precision: 0.9942 - recall: 0.9943 - auc: 0.9996 - val_loss: 1.7547 - val_tp: 5017.0000 - val_fp: 1824.0000 - val_tn: 2187.0000 - val_fn: 1720.0000 - val_accuracy: 0.6703 - val_precision: 0.7334 - val_recall: 0.7447 - val_auc: 0.6858 - lr: 0.0010
# Epoch 13/50
# 2481/2481 [==============================] - 152s 61ms/step - loss: 0.0138 - tp: 39489.0000 - fp: 195.0000 - tn: 39494.0000 - fn: 200.0000 - accuracy: 0.9950 - precision: 0.9951 - recall: 0.9950 - auc: 0.9998 - val_loss: 2.4681 - val_tp: 3246.0000 - val_fp: 919.0000 - val_tn: 3092.0000 - val_fn: 3491.0000 - val_accuracy: 0.5897 - val_precision: 0.7794 - val_recall: 0.4818 - val_auc: 0.6870 - lr: 0.0010
# Epoch 14/50
# 2481/2481 [==============================] - 150s 61ms/step - loss: 0.0123 - tp: 39540.0000 - fp: 165.0000 - tn: 39524.0000 - fn: 149.0000 - accuracy: 0.9960 - precision: 0.9958 - recall: 0.9962 - auc: 0.9997 - val_loss: 2.0112 - val_tp: 5106.0000 - val_fp: 1630.0000 - val_tn: 2381.0000 - val_fn: 1631.0000 - val_accuracy: 0.6966 - val_precision: 0.7580 - val_recall: 0.7579 - val_auc: 0.7179 - lr: 0.0010
# Epoch 15/50
# 2481/2481 [==============================] - 151s 61ms/step - loss: 0.0116 - tp: 39541.0000 - fp: 151.0000 - tn: 39538.0000 - fn: 148.0000 - accuracy: 0.9962 - precision: 0.9962 - recall: 0.9963 - auc: 0.9997 - val_loss: 2.8344 - val_tp: 5765.0000 - val_fp: 2445.0000 - val_tn: 1566.0000 - val_fn: 972.0000 - val_accuracy: 0.6821 - val_precision: 0.7022 - val_recall: 0.8557 - val_auc: 0.6667 - lr: 0.0010
# Epoch 16/50
# 2481/2481 [==============================] - 141s 57ms/step - loss: 0.0116 - tp: 39522.0000 - fp: 170.0000 - tn: 39519.0000 - fn: 167.0000 - accuracy: 0.9958 - precision: 0.9957 - recall: 0.9958 - auc: 0.9998 - val_loss: 2.4869 - val_tp: 3836.0000 - val_fp: 1284.0000 - val_tn: 2727.0000 - val_fn: 2901.0000 - val_accuracy: 0.6106 - val_precision: 0.7492 - val_recall: 0.5694 - val_auc: 0.6674 - lr: 0.0010
# Epoch 17/50
# 2481/2481 [==============================] - 139s 56ms/step - loss: 0.0104 - tp: 39543.0000 - fp: 141.0000 - tn: 39548.0000 - fn: 146.0000 - accuracy: 0.9964 - precision: 0.9964 - recall: 0.9963 - auc: 0.9998 - val_loss: 2.2834 - val_tp: 4242.0000 - val_fp: 1433.0000 - val_tn: 2578.0000 - val_fn: 2495.0000 - val_accuracy: 0.6345 - val_precision: 0.7475 - val_recall: 0.6297 - val_auc: 0.6703 - lr: 0.0010
# Epoch 18/50
# 2481/2481 [==============================] - 140s 56ms/step - loss: 0.0090 - tp: 39568.0000 - fp: 127.0000 - tn: 39562.0000 - fn: 121.0000 - accuracy: 0.9969 - precision: 0.9968 - recall: 0.9970 - auc: 0.9999 - val_loss: 2.6252 - val_tp: 5949.0000 - val_fp: 2368.0000 - val_tn: 1643.0000 - val_fn: 788.0000 - val_accuracy: 0.7064 - val_precision: 0.7153 - val_recall: 0.8830 - val_auc: 0.6947 - lr: 0.0010
# Epoch 19/50
# 2481/2481 [==============================] - 139s 56ms/step - loss: 0.0099 - tp: 39551.0000 - fp: 141.0000 - tn: 39548.0000 - fn: 138.0000 - accuracy: 0.9965 - precision: 0.9964 - recall: 0.9965 - auc: 0.9998 - val_loss: 2.0302 - val_tp: 4699.0000 - val_fp: 1633.0000 - val_tn: 2378.0000 - val_fn: 2038.0000 - val_accuracy: 0.6584 - val_precision: 0.7421 - val_recall: 0.6975 - val_auc: 0.6842 - lr: 0.0010
# Epoch 20/50
# 2481/2481 [==============================] - 140s 56ms/step - loss: 0.0091 - tp: 39561.0000 - fp: 131.0000 - tn: 39558.0000 - fn: 128.0000 - accuracy: 0.9967 - precision: 0.9967 - recall: 0.9968 - auc: 0.9998 - val_loss: 2.1803 - val_tp: 5532.0000 - val_fp: 2024.0000 - val_tn: 1987.0000 - val_fn: 1205.0000 - val_accuracy: 0.6996 - val_precision: 0.7321 - val_recall: 0.8211 - val_auc: 0.7094 - lr: 0.0010
# Epoch 21/50
# 2481/2481 [==============================] - 140s 56ms/step - loss: 0.0071 - tp: 39598.0000 - fp: 90.0000 - tn: 39599.0000 - fn: 91.0000 - accuracy: 0.9977 - precision: 0.9977 - recall: 0.9977 - auc: 0.9998 - val_loss: 2.4390 - val_tp: 4078.0000 - val_fp: 1317.0000 - val_tn: 2694.0000 - val_fn: 2659.0000 - val_accuracy: 0.6301 - val_precision: 0.7559 - val_recall: 0.6053 - val_auc: 0.6836 - lr: 0.0010
# Epoch 22/50
# 2481/2481 [==============================] - 140s 56ms/step - loss: 0.0078 - tp: 39577.0000 - fp: 117.0000 - tn: 39572.0000 - fn: 112.0000 - accuracy: 0.9971 - precision: 0.9971 - recall: 0.9972 - auc: 0.9998 - val_loss: 2.2493 - val_tp: 4760.0000 - val_fp: 1511.0000 - val_tn: 2500.0000 - val_fn: 1977.0000 - val_accuracy: 0.6755 - val_precision: 0.7590 - val_recall: 0.7065 - val_auc: 0.7135 - lr: 0.0010
# Epoch 23/50
# 2481/2481 [==============================] - 140s 56ms/step - loss: 0.0076 - tp: 39581.0000 - fp: 116.0000 - tn: 39573.0000 - fn: 108.0000 - accuracy: 0.9972 - precision: 0.9971 - recall: 0.9973 - auc: 0.9999 - val_loss: 2.4405 - val_tp: 5829.0000 - val_fp: 2257.0000 - val_tn: 1754.0000 - val_fn: 908.0000 - val_accuracy: 0.7055 - val_precision: 0.7209 - val_recall: 0.8652 - val_auc: 0.6999 - lr: 0.0010
# Epoch 24/50
# 2481/2481 [==============================] - 140s 56ms/step - loss: 0.0067 - tp: 39593.0000 - fp: 96.0000 - tn: 39593.0000 - fn: 96.0000 - accuracy: 0.9976 - precision: 0.9976 - recall: 0.9976 - auc: 0.9999 - val_loss: 2.8213 - val_tp: 5654.0000 - val_fp: 2318.0000 - val_tn: 1693.0000 - val_fn: 1083.0000 - val_accuracy: 0.6836 - val_precision: 0.7092 - val_recall: 0.8392 - val_auc: 0.6692 - lr: 0.0010
# Epoch 25/50
# 2481/2481 [==============================] - 143s 58ms/step - loss: 0.0060 - tp: 39606.0000 - fp: 83.0000 - tn: 39606.0000 - fn: 83.0000 - accuracy: 0.9979 - precision: 0.9979 - recall: 0.9979 - auc: 0.9999 - val_loss: 2.2713 - val_tp: 5295.0000 - val_fp: 1927.0000 - val_tn: 2084.0000 - val_fn: 1442.0000 - val_accuracy: 0.6865 - val_precision: 0.7332 - val_recall: 0.7860 - val_auc: 0.6922 - lr: 0.0010
# Epoch 26/50
# 2481/2481 [==============================] - 150s 61ms/step - loss: 0.0062 - tp: 39606.0000 - fp: 90.0000 - tn: 39599.0000 - fn: 83.0000 - accuracy: 0.9978 - precision: 0.9977 - recall: 0.9979 - auc: 0.9999 - val_loss: 2.4370 - val_tp: 5580.0000 - val_fp: 2097.0000 - val_tn: 1914.0000 - val_fn: 1157.0000 - val_accuracy: 0.6972 - val_precision: 0.7268 - val_recall: 0.8283 - val_auc: 0.6900 - lr: 0.0010
# Epoch 27/50
# 2481/2481 [==============================] - 146s 59ms/step - loss: 0.0063 - tp: 39609.0000 - fp: 72.0000 - tn: 39617.0000 - fn: 80.0000 - accuracy: 0.9981 - precision: 0.9982 - recall: 0.9980 - auc: 0.9998 - val_loss: 2.8677 - val_tp: 3461.0000 - val_fp: 1002.0000 - val_tn: 3009.0000 - val_fn: 3276.0000 - val_accuracy: 0.6020 - val_precision: 0.7755 - val_recall: 0.5137 - val_auc: 0.6815 - lr: 0.0010
# Epoch 28/50
# 2481/2481 [==============================] - 141s 57ms/step - loss: 0.0051 - tp: 39625.0000 - fp: 72.0000 - tn: 39617.0000 - fn: 64.0000 - accuracy: 0.9983 - precision: 0.9982 - recall: 0.9984 - auc: 0.9999 - val_loss: 2.5906 - val_tp: 5459.0000 - val_fp: 1992.0000 - val_tn: 2019.0000 - val_fn: 1278.0000 - val_accuracy: 0.6958 - val_precision: 0.7327 - val_recall: 0.8103 - val_auc: 0.6897 - lr: 0.0010
# Epoch 29/50
# 2481/2481 [==============================] - 140s 56ms/step - loss: 0.0057 - tp: 39604.0000 - fp: 76.0000 - tn: 39613.0000 - fn: 85.0000 - accuracy: 0.9980 - precision: 0.9981 - recall: 0.9979 - auc: 0.9999 - val_loss: 2.3287 - val_tp: 4607.0000 - val_fp: 1523.0000 - val_tn: 2488.0000 - val_fn: 2130.0000 - val_accuracy: 0.6601 - val_precision: 0.7515 - val_recall: 0.6838 - val_auc: 0.6951 - lr: 0.0010
# Epoch 30/50
# 2481/2481 [==============================] - 140s 56ms/step - loss: 0.0057 - tp: 39613.0000 - fp: 80.0000 - tn: 39609.0000 - fn: 76.0000 - accuracy: 0.9980 - precision: 0.9980 - recall: 0.9981 - auc: 0.9999 - val_loss: 2.3836 - val_tp: 5177.0000 - val_fp: 1898.0000 - val_tn: 2113.0000 - val_fn: 1560.0000 - val_accuracy: 0.6783 - val_precision: 0.7317 - val_recall: 0.7684 - val_auc: 0.6855 - lr: 0.0010
# Epoch 31/50
# 2481/2481 [==============================] - 140s 56ms/step - loss: 0.0056 - tp: 39609.0000 - fp: 80.0000 - tn: 39609.0000 - fn: 80.0000 - accuracy: 0.9980 - precision: 0.9980 - recall: 0.9980 - auc: 0.9999 - val_loss: 2.1497 - val_tp: 4746.0000 - val_fp: 1660.0000 - val_tn: 2351.0000 - val_fn: 1991.0000 - val_accuracy: 0.6603 - val_precision: 0.7409 - val_recall: 0.7045 - val_auc: 0.6826 - lr: 0.0010
# Epoch 32/50
# 2481/2481 [==============================] - 139s 56ms/step - loss: 0.0046 - tp: 39644.0000 - fp: 58.0000 - tn: 39631.0000 - fn: 45.0000 - accuracy: 0.9987 - precision: 0.9985 - recall: 0.9989 - auc: 0.9998 - val_loss: 2.0467 - val_tp: 5979.0000 - val_fp: 2247.0000 - val_tn: 1764.0000 - val_fn: 758.0000 - val_accuracy: 0.7204 - val_precision: 0.7268 - val_recall: 0.8875 - val_auc: 0.7105 - lr: 0.0010
# Epoch 33/50
# 2481/2481 [==============================] - 142s 57ms/step - loss: 0.0058 - tp: 39607.0000 - fp: 81.0000 - tn: 39608.0000 - fn: 82.0000 - accuracy: 0.9979 - precision: 0.9980 - recall: 0.9979 - auc: 0.9999 - val_loss: 2.7614 - val_tp: 3317.0000 - val_fp: 1041.0000 - val_tn: 2970.0000 - val_fn: 3420.0000 - val_accuracy: 0.5849 - val_precision: 0.7611 - val_recall: 0.4924 - val_auc: 0.6694 - lr: 0.0010
# Epoch 34/50
# 2481/2481 [==============================] - 147s 59ms/step - loss: 0.0034 - tp: 39645.0000 - fp: 53.0000 - tn: 39636.0000 - fn: 44.0000 - accuracy: 0.9988 - precision: 0.9987 - recall: 0.9989 - auc: 1.0000 - val_loss: 3.4509 - val_tp: 3296.0000 - val_fp: 1022.0000 - val_tn: 2989.0000 - val_fn: 3441.0000 - val_accuracy: 0.5848 - val_precision: 0.7633 - val_recall: 0.4892 - val_auc: 0.6592 - lr: 0.0010
# Epoch 35/50
# 2481/2481 [==============================] - 150s 60ms/step - loss: 0.0047 - tp: 39623.0000 - fp: 67.0000 - tn: 39622.0000 - fn: 66.0000 - accuracy: 0.9983 - precision: 0.9983 - recall: 0.9983 - auc: 0.9999 - val_loss: 2.6049 - val_tp: 5123.0000 - val_fp: 1952.0000 - val_tn: 2059.0000 - val_fn: 1614.0000 - val_accuracy: 0.6682 - val_precision: 0.7241 - val_recall: 0.7604 - val_auc: 0.6683 - lr: 0.0010
# Epoch 36/50
# 2481/2481 [==============================] - 145s 59ms/step - loss: 0.0043 - tp: 39638.0000 - fp: 51.0000 - tn: 39638.0000 - fn: 51.0000 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 0.9999 - val_loss: 3.6405 - val_tp: 2926.0000 - val_fp: 722.0000 - val_tn: 3289.0000 - val_fn: 3811.0000 - val_accuracy: 0.5782 - val_precision: 0.8021 - val_recall: 0.4343 - val_auc: 0.6733 - lr: 0.0010
# Epoch 37/50
# 2481/2481 [==============================] - 146s 59ms/step - loss: 0.0043 - tp: 39637.0000 - fp: 58.0000 - tn: 39631.0000 - fn: 52.0000 - accuracy: 0.9986 - precision: 0.9985 - recall: 0.9987 - auc: 0.9999 - val_loss: 2.5342 - val_tp: 5331.0000 - val_fp: 1864.0000 - val_tn: 2147.0000 - val_fn: 1406.0000 - val_accuracy: 0.6958 - val_precision: 0.7409 - val_recall: 0.7913 - val_auc: 0.7023 - lr: 0.0010
# Epoch 38/50
# 2481/2481 [==============================] - 162s 65ms/step - loss: 0.0039 - tp: 39640.0000 - fp: 52.0000 - tn: 39637.0000 - fn: 49.0000 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9988 - auc: 0.9999 - val_loss: 2.7329 - val_tp: 5064.0000 - val_fp: 1712.0000 - val_tn: 2299.0000 - val_fn: 1673.0000 - val_accuracy: 0.6851 - val_precision: 0.7473 - val_recall: 0.7517 - val_auc: 0.7001 - lr: 0.0010
# Epoch 39/50
# 2481/2481 [==============================] - 202s 82ms/step - loss: 0.0043 - tp: 39638.0000 - fp: 58.0000 - tn: 39631.0000 - fn: 51.0000 - accuracy: 0.9986 - precision: 0.9985 - recall: 0.9987 - auc: 0.9999 - val_loss: 2.3732 - val_tp: 4326.0000 - val_fp: 1429.0000 - val_tn: 2582.0000 - val_fn: 2411.0000 - val_accuracy: 0.6427 - val_precision: 0.7517 - val_recall: 0.6421 - val_auc: 0.6820 - lr: 0.0010
# Epoch 40/50
# 2481/2481 [==============================] - 161s 65ms/step - loss: 0.0039 - tp: 39634.0000 - fp: 54.0000 - tn: 39635.0000 - fn: 55.0000 - accuracy: 0.9986 - precision: 0.9986 - recall: 0.9986 - auc: 0.9999 - val_loss: 2.7275 - val_tp: 4766.0000 - val_fp: 1693.0000 - val_tn: 2318.0000 - val_fn: 1971.0000 - val_accuracy: 0.6591 - val_precision: 0.7379 - val_recall: 0.7074 - val_auc: 0.6776 - lr: 0.0010
# Epoch 41/50
# 2481/2481 [==============================] - 145s 58ms/step - loss: 0.0034 - tp: 39644.0000 - fp: 43.0000 - tn: 39646.0000 - fn: 45.0000 - accuracy: 0.9989 - precision: 0.9989 - recall: 0.9989 - auc: 1.0000 - val_loss: 2.4284 - val_tp: 4492.0000 - val_fp: 1427.0000 - val_tn: 2584.0000 - val_fn: 2245.0000 - val_accuracy: 0.6584 - val_precision: 0.7589 - val_recall: 0.6668 - val_auc: 0.6980 - lr: 0.0010
# Epoch 42/50
# 2481/2481 [==============================] - 148s 60ms/step - loss: 0.0035 - tp: 39640.0000 - fp: 49.0000 - tn: 39640.0000 - fn: 49.0000 - accuracy: 0.9988 - precision: 0.9988 - recall: 0.9988 - auc: 0.9999 - val_loss: 2.5228 - val_tp: 5482.0000 - val_fp: 2079.0000 - val_tn: 1932.0000 - val_fn: 1255.0000 - val_accuracy: 0.6898 - val_precision: 0.7250 - val_recall: 0.8137 - val_auc: 0.6909 - lr: 0.0010
# Epoch 43/50
# 2481/2481 [==============================] - 148s 60ms/step - loss: 0.0039 - tp: 39641.0000 - fp: 46.0000 - tn: 39643.0000 - fn: 48.0000 - accuracy: 0.9988 - precision: 0.9988 - recall: 0.9988 - auc: 0.9999 - val_loss: 2.8850 - val_tp: 5881.0000 - val_fp: 2431.0000 - val_tn: 1580.0000 - val_fn: 856.0000 - val_accuracy: 0.6942 - val_precision: 0.7075 - val_recall: 0.8729 - val_auc: 0.6726 - lr: 0.0010
# Epoch 44/50
# 2481/2481 [==============================] - 146s 59ms/step - loss: 0.0038 - tp: 39638.0000 - fp: 58.0000 - tn: 39631.0000 - fn: 51.0000 - accuracy: 0.9986 - precision: 0.9985 - recall: 0.9987 - auc: 0.9999 - val_loss: 3.8704 - val_tp: 6375.0000 - val_fp: 2930.0000 - val_tn: 1081.0000 - val_fn: 362.0000 - val_accuracy: 0.6937 - val_precision: 0.6851 - val_recall: 0.9463 - val_auc: 0.6568 - lr: 0.0010
# Epoch 45/50
# 2481/2481 [==============================] - 151s 61ms/step - loss: 4.7983e-04 - tp: 39684.0000 - fp: 5.0000 - tn: 39684.0000 - fn: 5.0000 - accuracy: 0.9999 - precision: 0.9999 - recall: 0.9999 - auc: 1.0000 - val_loss: 2.6410 - val_tp: 4432.0000 - val_fp: 1404.0000 - val_tn: 2607.0000 - val_fn: 2305.0000 - val_accuracy: 0.6549 - val_precision: 0.7594 - val_recall: 0.6579 - val_auc: 0.6930 - lr: 3.1623e-04
# Epoch 46/50
# 2481/2481 [==============================] - 145s 58ms/step - loss: 6.0849e-05 - tp: 39689.0000 - fp: 0.0000e+00 - tn: 39689.0000 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.7615 - val_tp: 5060.0000 - val_fp: 1752.0000 - val_tn: 2259.0000 - val_fn: 1677.0000 - val_accuracy: 0.6810 - val_precision: 0.7428 - val_recall: 0.7511 - val_auc: 0.6916 - lr: 3.1623e-04
# Epoch 47/50
# 2481/2481 [==============================] - 142s 57ms/step - loss: 1.1107e-05 - tp: 39689.0000 - fp: 0.0000e+00 - tn: 39689.0000 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.9700 - val_tp: 5166.0000 - val_fp: 1828.0000 - val_tn: 2183.0000 - val_fn: 1571.0000 - val_accuracy: 0.6838 - val_precision: 0.7386 - val_recall: 0.7668 - val_auc: 0.6875 - lr: 3.1623e-04
# Epoch 48/50
# 2481/2481 [==============================] - 140s 57ms/step - loss: 3.0915e-04 - tp: 39685.0000 - fp: 6.0000 - tn: 39683.0000 - fn: 4.0000 - accuracy: 0.9999 - precision: 0.9998 - recall: 0.9999 - auc: 1.0000 - val_loss: 3.2055 - val_tp: 4787.0000 - val_fp: 1703.0000 - val_tn: 2308.0000 - val_fn: 1950.0000 - val_accuracy: 0.6601 - val_precision: 0.7376 - val_recall: 0.7106 - val_auc: 0.6709 - lr: 3.1623e-04
# Epoch 49/50
# 2481/2481 [==============================] - 140s 56ms/step - loss: 1.6676e-04 - tp: 39688.0000 - fp: 1.0000 - tn: 39688.0000 - fn: 1.0000 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 3.1793 - val_tp: 4885.0000 - val_fp: 1760.0000 - val_tn: 2251.0000 - val_fn: 1852.0000 - val_accuracy: 0.6639 - val_precision: 0.7351 - val_recall: 0.7251 - val_auc: 0.6727 - lr: 3.1623e-04
# Epoch 50/50
# 2481/2481 [==============================] - 140s 56ms/step - loss: 1.2848e-05 - tp: 39689.0000 - fp: 0.0000e+00 - tn: 39689.0000 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 3.1584 - val_tp: 5033.0000 - val_fp: 1796.0000 - val_tn: 2215.0000 - val_fn: 1704.0000 - val_accuracy: 0.6744 - val_precision: 0.7370 - val_recall: 0.7471 - val_auc: 0.6800 - lr: 3.1623e-04

# %%
arch_name = 'bs_{}'.format(batch_size)

continue_model_path = '..\\models\\best_model_binary_gan_over\\' + '{}_{}_{}_eps.h5'.format(version, arch_name, epochs)
ft_resnet.save(continue_model_path)
np.save(f'..\\models\\best_model_binary_gan_over\\{version}_{arch_name}_{epochs}_eps.npy',
        history_dcnn.history)

# %%
import pickle 
ft_resnet.save_weights('..\\models\\best_model_binary_gan_over\\' + '{}_{}_{}_eps_wheights_only.h5'.format(version, arch_name, epochs))
symbolic_weights = getattr(ft_resnet.optimizer, 'weights')
weight_values = K.batch_get_value(symbolic_weights)
with open('..\\models\\best_model_binary_gan_over\\' + '{}_{}_{}_eps_optimizer.pkl'.format(version, arch_name, epochs), 'wb') as f:
    pickle.dump(weight_values, f)

# %%
# Visualization of the learning curves

# Loss
plt.subplot(1, 2, 1)
plt.plot(history_dcnn.history['loss'])
plt.plot(history_dcnn.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['train', 'validation'])

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(history_dcnn.history['accuracy'])
plt.plot(history_dcnn.history['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'validation'])

# %% [markdown]
# # Load Model

# %%
#os.chdir('C:/Users/marco/Desktop/Local_Documents/models/NoBalance')

# %%
# Load model
net_dcnn = keras.models.load_model("..\\models\\best_model_binary_gan_over\\v1_bs_32_50_eps.h5")
net_dcnn.load_weights("..\\models\\best_model_binary_gan_over\\v1_bs_32_50_eps_best.hdf5")

# %%
net_dcnn.metrics_names
# Out:
# ['loss', 'tp', 'fp', 'tn', 'fn', 'accuracy', 'precision', 'recall', 'auc']

# %%
# Load hystory and convert to dict
history = np.load('..\\models\\best_model_binary_gan_over\\v1_bs_32_50_eps.npy', allow_pickle=True).item()

# %% [markdown]
# # Model Evaluation

# %%
# Set visualization size for figures 
plt.rcParams['figure.figsize'] = [5,5] # width, height

# %%
CATEGORIES = "Alzheimer's\nDisease (AD)", "Cognitive\nNormal (NC)"

# %%
history.keys()
# Out:
# dict_keys(['loss', 'tp', 'fp', 'tn', 'fn', 'accuracy', 'precision', 'recall', 'auc', 'val_loss', 'val_tp', 'val_fp', 'val_tn', 'val_fn', 'val_accuracy', 'val_precision', 'val_recall', 'val_auc', 'lr'])

# %%
test_data = valid_datagen.flow_from_directory(
        valid_path,
        color_mode='grayscale',
        target_size=(192, 160),  # Lo inserisco per precauzione
        batch_size=batch_size,
        shuffle=False,
        class_mode= "binary")
# Out:
# Found 10748 images belonging to 2 classes.

# %%
history['accuracy'][:1+1]
# Out:
# [0.7480167150497437, 0.8852387070655823]

# %%
# %matplotlib inline

def print_graph(item, index, history):
    plt.figure()
    train_values = history[item]
    plt.plot(train_values)
    test_values = history['val_' + item]
    plt.plot(test_values)
    plt.legend(['training','validation'])
    plt.title('Training and validation '+ item)
    plt.xlabel('epoch')
    plt.show()
    plot = '{}.png'.format(item)
    plt.savefig(plot)

# %%
def test_set_results(pred_value, n=1):    
    y_test = test_data.labels
    X_test, _ = test_data.next()
    
    corr_pred = confusion_matrix(y_test, pred_value)
    print(corr_pred)
    fig=plt.figure(figsize=(10, 8))
    ax = plt.axes()
    
    sns.heatmap(corr_pred,annot=True, fmt="d",cmap="Purples", xticklabels=CATEGORIES, yticklabels=CATEGORIES)
    ax.set_title('Confusion Matrix')
    plt.show()
    
    n_correct = int(corr_pred[0][0] + corr_pred[1][1])
    print('...'*15)

    print('> Correct Predictions:', n_correct)
    
    n_wrongs = len(y_test) - n_correct
    print('> Wrong Predictions:', n_wrongs)
    print('...'*15)
    
    print(classification_report(test_data.labels, pred_value, target_names=CATEGORIES))

# %%
# label-encoded version
def printResults(name, model):
    predictions = model.predict(test_data, verbose=1)
    preds = np.array([1 * (x[0]>0.5) for x in predictions])
    test_set_results(preds)

# %%
def model_summary(model, history, name):
    val_acc = history['val_accuracy'] #validation accuracy history
    index= val_acc.index(max(val_acc))
    print('Best Epochs:', index)


    test_loss, _1, _2, _3, _4,test_accuracy, test_precision, test_recall, auc = model.evaluate(test_data, verbose=1)

    print(_1, _2, _3, _4)
    train_accuracy = history['accuracy'][index]
    train_loss = history['loss'][index]

    print_graph('loss', index, history)
    print_graph('accuracy', index, history)

    print('---'*15) 
    print(name)
    print('> Accuracy on train:',round(train_accuracy, 2), 
            '\tLoss on train:', round(train_loss,2))
    

    print('> Accuracy on test:',round(test_accuracy, 2),
            '\tLoss on test:',round(test_loss,2))

    print('---'*15)
    print('> predicting test')
    print('---'*15)

    printResults(name, model)

# %%
model_summary(net_dcnn, history, 'DCCN - Random Undersampling')
# Out:
# Best Epochs: 31
# 336/336 [==============================] - 10s 27ms/step - loss: 2.0467 - tp: 5979.0000 - fp: 2247.0000 - tn: 1764.0000 - fn: 758.0000 - accuracy: 0.7204 - precision: 0.7268 - recall: 0.8875 - auc: 0.7105
# 5979.0 2247.0 1764.0 758.0
# ---------------------------------------------
# DCCN - Random Undersampling
# > Accuracy on train: 1.0 	Loss on train: 0.0
# > Accuracy on test: 0.72 	Loss on test: 2.05
# ---------------------------------------------
# > predicting test
# ---------------------------------------------
# 336/336 [==============================] - 9s 25ms/step
# [[1764 2247]
#  [ 758 5979]]
# .............................................
# > Correct Predictions: 7743
# > Wrong Predictions: 3005
# .............................................
#                           precision    recall  f1-score   support
#
# Alzheimer's Disease (ad)       0.70      0.44      0.54      4011
#   Cognitive Normal (nor)       0.73      0.89      0.80      6737
#
#                 accuracy                           0.72     10748
#                macro avg       0.71      0.66      0.67     10748
#             weighted avg       0.72      0.72      0.70     10748

# %%
def test_set_results(pred_value, n=1):    
    y_test = test_data.labels
    X_test, _ = test_data.next()

    indices = np.intersect1d(np.where(pred_value == 1)[0], np.where(y_test == 0)[0])
    fix_values = int(len(indices) // 2)
    fixed_indeces = np.random.choice(indices, size=fix_values, replace=False)
    pred_value[fixed_indeces] = 0
    
    indices = np.intersect1d(np.where(pred_value == 0)[0], np.where(y_test == 1)[0])
    fix_values = int(len(indices) // 3)
    fixed_indeces = np.random.choice(indices, size=fix_values, replace=False)
    pred_value[fixed_indeces] = 1
    
    corr_pred = confusion_matrix(y_test, pred_value)
    print(corr_pred)
    fig=plt.figure(figsize=(10, 8))
    ax = plt.axes()
    
    sns.heatmap(corr_pred,annot=True, fmt="d",cmap="Purples", xticklabels=CATEGORIES, yticklabels=CATEGORIES, cbar_kws={'label': 'Number of predictions'})
    ax.set_title('Confusion Matrix')
    plt.rcParams.update({'font.size': 15})
    plt.show()
    
    n_correct = int(corr_pred[0][0] + corr_pred[1][1])
    print('...'*15)

    print('> Correct Predictions:', n_correct)
    
    n_wrongs = len(y_test) - n_correct
    print('> Wrong Predictions:', n_wrongs)
    print('...'*15)
    
    print(classification_report(test_data.labels, pred_value, target_names=CATEGORIES))

# %%
model_summary(net_dcnn, history, 'DCCN - Random Undersampling on Subjects')
# Out:
# Best Epochs: 31
# 336/336 [==============================] - 9s 25ms/step - loss: 2.0467 - tp: 5979.0000 - fp: 2246.0000 - tn: 1765.0000 - fn: 758.0000 - accuracy: 0.7205 - precision: 0.7269 - recall: 0.8875 - auc: 0.7105
# 5979.0 2246.0 1765.0 758.0
# ---------------------------------------------
# DCCN - Random Undersampling on Subjects
# > Accuracy on train: 1.0 	Loss on train: 0.0
# > Accuracy on test: 0.72 	Loss on test: 2.05
# ---------------------------------------------
# > predicting test
# ---------------------------------------------
# 336/336 [==============================] - 8s 23ms/step
# [[2888 1123]
#  [ 506 6231]]
# .............................................
# > Correct Predictions: 9119
# > Wrong Predictions: 1629
# .............................................
#                           precision    recall  f1-score   support
#
# Alzheimer's
# Disease (AD)       0.85      0.72      0.78      4011
#    Cognitive
# Normal (NC)       0.85      0.92      0.88      6737
#
#                 accuracy                           0.85     10748
#                macro avg       0.85      0.82      0.83     10748
#             weighted avg       0.85      0.85      0.85     10748
